# %%
import torch
import torch.nn as nn
import torch.optim as optim

# 간단한 다층 퍼셉트론 모델 정의
class SimpleMLP(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(SimpleMLP, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.layer2 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.layer1(x)
        x = self.relu(x)
        x = self.layer2(x)
        return x

# 모델 인스턴스 생성
input_size = 10
hidden_size = 20
output_size = 2
model = SimpleMLP(input_size, hidden_size, output_size)

# 손실 함수와 옵티마이저 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# 가상의 입력 데이터 생성
x = torch.randn(5, input_size)
y = torch.randint(0, output_size, (5,))

for epoch in range(1000):
  # 순전파 및 역전파
  optimizer.zero_grad()
  outputs = model(x)
  loss = criterion(outputs, y)
  loss.backward()
  optimizer.step()

  if (epoch+1) % 200 == 0:
        print(f'Epoch {epoch+1}, Loss: {loss.item():.4f}')

print(f"모델 구조: {model}")
print(f"손실값: {loss.item()}")
# Out:
# Epoch 200, Loss: 0.2663
# Epoch 400, Loss: 0.0957
# Epoch 600, Loss: 0.0485
# Epoch 800, Loss: 0.0302
# Epoch 1000, Loss: 0.0211
# 모델 구조: SimpleMLP(
#   (layer1): Linear(in_features=10, out_features=20, bias=True)
#   (relu): ReLU()
#   (layer2): Linear(in_features=20, out_features=2, bias=True)
# )
# 손실값: 0.02113472670316696

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# 1) 모델 정의: Sequential API 사용
model = Sequential([
    Dense(20, activation='relu', input_shape=(10,)),  # 은닉층
    Dense(2)                                         # 출력층 (logits 출력)
])

# 2) 컴파일: 옵티마이저, 손실함수, 평가 지표 설정
model.compile(
    optimizer=SGD(learning_rate=0.01),
    loss=SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# 3) 가상의 입력 및 레이블 데이터 생성
x = tf.random.normal((5, 10))                               # (배치크기=5, 특성=10)
y = tf.random.uniform((5,), minval=0, maxval=2, dtype=tf.int32)  # 정수 레이블 0 또는 1

# 4) 학습: epochs=1, batch_size=5
history = model.fit(x, y, epochs=1000, batch_size=5)

# 5) 결과 출력
print("\n모델 구조:")
model.summary()
print(f"\n최종 손실값: {history.history['loss'][0]:.4f}")
print(f"최종 정확도: {history.history['accuracy'][0]:.4f}")
# Out:
# Epoch 1/1000
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step - accuracy: 0.6000 - loss: 0.7149
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.6984
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6000 - loss: 0.6823
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6000 - loss: 0.6667
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6000 - loss: 0.6516
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6000 - loss: 0.6370
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.6228
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.6090
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5957
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6000 - loss: 0.5828
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5703
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.5582
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6000 - loss: 0.5464
# Epoch 14/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6000 - loss: 0.5350
# Epoch 15/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6000 - loss: 0.5240
# Epoch 16/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.5133
# Epoch 17/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6000 - loss: 0.5030
# Epoch 18/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6000 - loss: 0.4931
# Epoch 19/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8000 - loss: 0.4835
# Epoch 20/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8000 - loss: 0.4741
# Epoch 21/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8000 - loss: 0.4651
# Epoch 22/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8000 - loss: 0.4563
# Epoch 23/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8000 - loss: 0.4478
# Epoch 24/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.4395
# Epoch 25/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.4315
# Epoch 26/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.4237
# Epoch 27/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 1.0000 - loss: 0.4161
# Epoch 28/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.4087
# Epoch 29/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.4015
# Epoch 30/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.3945
# Epoch 31/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.3878
# Epoch 32/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.3812
# Epoch 33/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.3747
# Epoch 34/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.3685
# Epoch 35/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.3624
# Epoch 36/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.3565
# Epoch 37/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.3507
# Epoch 38/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.3451
# Epoch 39/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.3396
# Epoch 40/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.3343
# Epoch 41/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.3291
# Epoch 42/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.3240
# Epoch 43/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 1.0000 - loss: 0.3190
# Epoch 44/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.3142
# Epoch 45/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.3095
# Epoch 46/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.3049
# Epoch 47/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.3004
# Epoch 48/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.2960
# Epoch 49/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.2917
# Epoch 50/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.2875
# Epoch 51/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.2834
# Epoch 52/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.2794
# Epoch 53/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.2755
# Epoch 54/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.2717
# Epoch 55/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.2679
# Epoch 56/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.2643
# Epoch 57/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.2607
# Epoch 58/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.2572
# Epoch 59/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.2538
# Epoch 60/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.2505
# Epoch 61/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.2472
# Epoch 62/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.2440
# Epoch 63/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.2408
# Epoch 64/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.2377
# Epoch 65/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.2347
# Epoch 66/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.2318
# Epoch 67/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.2289
# Epoch 68/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.2261
# Epoch 69/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.2234
# Epoch 70/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.2208
# Epoch 71/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.2182
# Epoch 72/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.2156
# Epoch 73/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.2131
# Epoch 74/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.2106
# Epoch 75/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.2082
# Epoch 76/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.2059
# Epoch 77/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.2036
# Epoch 78/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.2013
# Epoch 79/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.1991
# Epoch 80/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1970
# Epoch 81/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1948
# Epoch 82/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.1928
# Epoch 83/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1907
# Epoch 84/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.1887
# Epoch 85/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.1868
# Epoch 86/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.1848
# Epoch 87/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1830
# Epoch 88/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1812
# Epoch 89/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.1795
# Epoch 90/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.1777
# Epoch 91/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1760
# Epoch 92/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1744
# Epoch 93/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.1727
# Epoch 94/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1711
# Epoch 95/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1695
# Epoch 96/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.1679
# Epoch 97/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.1664
# Epoch 98/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1649
# Epoch 99/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.1634
# Epoch 100/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.1619
# Epoch 101/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.1604
# Epoch 102/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1590
# Epoch 103/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.1576
# Epoch 104/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.1562
# Epoch 105/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.1548
# Epoch 106/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.1535
# Epoch 107/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.1521
# Epoch 108/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.1508
# Epoch 109/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1495
# Epoch 110/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.1482
# Epoch 111/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.1470
# Epoch 112/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.1457
# Epoch 113/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.1445
# Epoch 114/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 0.1433
# Epoch 115/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.1421
# Epoch 116/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1409
# Epoch 117/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1398
# Epoch 118/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.1386
# Epoch 119/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.1375
# Epoch 120/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.1364
# Epoch 121/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.1353
# Epoch 122/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1342
# Epoch 123/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.1332
# Epoch 124/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1321
# Epoch 125/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1311
# Epoch 126/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1300
# Epoch 127/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.1290
# Epoch 128/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.1280
# Epoch 129/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.1270
# Epoch 130/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.1261
# Epoch 131/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1251
# Epoch 132/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1241
# Epoch 133/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1232
# Epoch 134/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.1223
# Epoch 135/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1214
# Epoch 136/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.1205
# Epoch 137/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.1196
# Epoch 138/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.1187
# Epoch 139/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.1178
# Epoch 140/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.1169
# Epoch 141/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.1161
# Epoch 142/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.1153
# Epoch 143/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.1144
# Epoch 144/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1136
# Epoch 145/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.1128
# Epoch 146/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.1120
# Epoch 147/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1112
# Epoch 148/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.1104
# Epoch 149/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.1096
# Epoch 150/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.1089
# Epoch 151/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.1081
# Epoch 152/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.1074
# Epoch 153/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1066
# Epoch 154/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1059
# Epoch 155/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1052
# Epoch 156/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.1045
# Epoch 157/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.1038
# Epoch 158/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.1031
# Epoch 159/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.1024
# Epoch 160/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.1017
# Epoch 161/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.1010
# Epoch 162/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.1004
# Epoch 163/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0997
# Epoch 164/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0990
# Epoch 165/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0984
# Epoch 166/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0978
# Epoch 167/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0971
# Epoch 168/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0965
# Epoch 169/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0959
# Epoch 170/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0953
# Epoch 171/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0947
# Epoch 172/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0941
# Epoch 173/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0935
# Epoch 174/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0929
# Epoch 175/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0923
# Epoch 176/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0918
# Epoch 177/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0912
# Epoch 178/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0906
# Epoch 179/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0901
# Epoch 180/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0896
# Epoch 181/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0890
# Epoch 182/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0885
# Epoch 183/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0879
# Epoch 184/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.0874
# Epoch 185/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0869
# Epoch 186/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0864
# Epoch 187/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0859
# Epoch 188/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0854
# Epoch 189/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0849
# Epoch 190/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0844
# Epoch 191/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0839
# Epoch 192/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0834
# Epoch 193/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0829
# Epoch 194/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0824
# Epoch 195/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0820
# Epoch 196/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0815
# Epoch 197/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0810
# Epoch 198/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0806
# Epoch 199/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0801
# Epoch 200/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0797
# Epoch 201/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0792
# Epoch 202/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0788
# Epoch 203/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0784
# Epoch 204/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0779
# Epoch 205/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0775
# Epoch 206/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0771
# Epoch 207/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0767
# Epoch 208/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0763
# Epoch 209/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0758
# Epoch 210/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0754
# Epoch 211/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0750
# Epoch 212/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0746
# Epoch 213/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0742
# Epoch 214/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 1.0000 - loss: 0.0738
# Epoch 215/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0734
# Epoch 216/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0731
# Epoch 217/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0727
# Epoch 218/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0723
# Epoch 219/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0719
# Epoch 220/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 0.0715
# Epoch 221/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0712
# Epoch 222/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0708
# Epoch 223/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0704
# Epoch 224/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0701
# Epoch 225/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0697
# Epoch 226/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0694
# Epoch 227/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 1.0000 - loss: 0.0690
# Epoch 228/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0687
# Epoch 229/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0683
# Epoch 230/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0680
# Epoch 231/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0677
# Epoch 232/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.0673
# Epoch 233/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0670
# Epoch 234/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0667
# Epoch 235/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0663
# Epoch 236/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0660
# Epoch 237/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0657
# Epoch 238/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0654
# Epoch 239/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0651
# Epoch 240/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0647
# Epoch 241/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0644
# Epoch 242/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0641
# Epoch 243/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0638
# Epoch 244/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0635
# Epoch 245/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0632
# Epoch 246/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0629
# Epoch 247/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0626
# Epoch 248/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0623
# Epoch 249/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0620
# Epoch 250/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0617
# Epoch 251/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0615
# Epoch 252/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0612
# Epoch 253/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0609
# Epoch 254/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0606
# Epoch 255/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0604
# Epoch 256/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0601
# Epoch 257/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0598
# Epoch 258/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0596
# Epoch 259/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0593
# Epoch 260/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0590
# Epoch 261/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0588
# Epoch 262/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0585
# Epoch 263/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0583
# Epoch 264/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0580
# Epoch 265/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0578
# Epoch 266/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0575
# Epoch 267/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 1.0000 - loss: 0.0573
# Epoch 268/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0570
# Epoch 269/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0568
# Epoch 270/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0565
# Epoch 271/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0563
# Epoch 272/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0561
# Epoch 273/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0558
# Epoch 274/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0556
# Epoch 275/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0554
# Epoch 276/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0551
# Epoch 277/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0549
# Epoch 278/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0547
# Epoch 279/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0544
# Epoch 280/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0542
# Epoch 281/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0540
# Epoch 282/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0538
# Epoch 283/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0535
# Epoch 284/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0533
# Epoch 285/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0531
# Epoch 286/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0529
# Epoch 287/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0527
# Epoch 288/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0525
# Epoch 289/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0522
# Epoch 290/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0520
# Epoch 291/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0518
# Epoch 292/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0516
# Epoch 293/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0514
# Epoch 294/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0512
# Epoch 295/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0510
# Epoch 296/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0508
# Epoch 297/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0506
# Epoch 298/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0504
# Epoch 299/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0502
# Epoch 300/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0500
# Epoch 301/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0498
# Epoch 302/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0496
# Epoch 303/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0494
# Epoch 304/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0492
# Epoch 305/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0490
# Epoch 306/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0489
# Epoch 307/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0487
# Epoch 308/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0485
# Epoch 309/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0483
# Epoch 310/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0481
# Epoch 311/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0479
# Epoch 312/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0478
# Epoch 313/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0476
# Epoch 314/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0474
# Epoch 315/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0472
# Epoch 316/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0470
# Epoch 317/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0469
# Epoch 318/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0467
# Epoch 319/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0465
# Epoch 320/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0463
# Epoch 321/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0462
# Epoch 322/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0460
# Epoch 323/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0458
# Epoch 324/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0457
# Epoch 325/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0455
# Epoch 326/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0453
# Epoch 327/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0452
# Epoch 328/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0450
# Epoch 329/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0448
# Epoch 330/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0447
# Epoch 331/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0445
# Epoch 332/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0444
# Epoch 333/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0442
# Epoch 334/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0440
# Epoch 335/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0439
# Epoch 336/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0437
# Epoch 337/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0436
# Epoch 338/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0434
# Epoch 339/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0433
# Epoch 340/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0431
# Epoch 341/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.0430
# Epoch 342/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0428
# Epoch 343/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0427
# Epoch 344/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0425
# Epoch 345/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0424
# Epoch 346/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0422
# Epoch 347/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0421
# Epoch 348/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0419
# Epoch 349/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0418
# Epoch 350/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0416
# Epoch 351/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0415
# Epoch 352/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0414
# Epoch 353/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0412
# Epoch 354/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0411
# Epoch 355/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0409
# Epoch 356/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0408
# Epoch 357/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0407
# Epoch 358/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0405
# Epoch 359/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0404
# Epoch 360/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0403
# Epoch 361/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0401
# Epoch 362/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0400
# Epoch 363/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0399
# Epoch 364/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0397
# Epoch 365/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0396
# Epoch 366/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0395
# Epoch 367/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0393
# Epoch 368/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0392
# Epoch 369/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0391
# Epoch 370/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0389
# Epoch 371/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0388
# Epoch 372/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0387
# Epoch 373/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0386
# Epoch 374/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0384
# Epoch 375/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0383
# Epoch 376/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0382
# Epoch 377/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0381
# Epoch 378/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0379
# Epoch 379/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0378
# Epoch 380/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0377
# Epoch 381/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0376
# Epoch 382/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0375
# Epoch 383/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0373
# Epoch 384/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0372
# Epoch 385/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0371
# Epoch 386/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0370
# Epoch 387/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 0.0369
# Epoch 388/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0368
# Epoch 389/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0366
# Epoch 390/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0365
# Epoch 391/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0364
# Epoch 392/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0363
# Epoch 393/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0362
# Epoch 394/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0361
# Epoch 395/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0360
# Epoch 396/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0359
# Epoch 397/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0357
# Epoch 398/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.0356
# Epoch 399/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0355
# Epoch 400/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0354
# Epoch 401/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.0353
# Epoch 402/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0352
# Epoch 403/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0351
# Epoch 404/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0350
# Epoch 405/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0349
# Epoch 406/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0348
# Epoch 407/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0347
# Epoch 408/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0346
# Epoch 409/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0345
# Epoch 410/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0344
# Epoch 411/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0343
# Epoch 412/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0342
# Epoch 413/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0341
# Epoch 414/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0340
# Epoch 415/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0339
# Epoch 416/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0338
# Epoch 417/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0337
# Epoch 418/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0336
# Epoch 419/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0335
# Epoch 420/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0334
# Epoch 421/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0333
# Epoch 422/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0332
# Epoch 423/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0331
# Epoch 424/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0330
# Epoch 425/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0329
# Epoch 426/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0328
# Epoch 427/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0327
# Epoch 428/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0326
# Epoch 429/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0325
# Epoch 430/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0324
# Epoch 431/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0323
# Epoch 432/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0322
# Epoch 433/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0321
# Epoch 434/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.0321
# Epoch 435/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0320
# Epoch 436/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0319
# Epoch 437/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0318
# Epoch 438/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0317
# Epoch 439/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0316
# Epoch 440/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0315
# Epoch 441/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0314
# Epoch 442/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0313
# Epoch 443/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0313
# Epoch 444/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0312
# Epoch 445/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0311
# Epoch 446/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0310
# Epoch 447/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0309
# Epoch 448/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0308
# Epoch 449/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0307
# Epoch 450/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0307
# Epoch 451/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0306
# Epoch 452/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0305
# Epoch 453/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0304
# Epoch 454/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0303
# Epoch 455/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0302
# Epoch 456/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0302
# Epoch 457/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0301
# Epoch 458/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0300
# Epoch 459/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.0299
# Epoch 460/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0298
# Epoch 461/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0298
# Epoch 462/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0297
# Epoch 463/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0296
# Epoch 464/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0295
# Epoch 465/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0294
# Epoch 466/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0294
# Epoch 467/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0293
# Epoch 468/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0292
# Epoch 469/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0291
# Epoch 470/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0290
# Epoch 471/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0290
# Epoch 472/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0289
# Epoch 473/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0288
# Epoch 474/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0287
# Epoch 475/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0287
# Epoch 476/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0286
# Epoch 477/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0285
# Epoch 478/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0284
# Epoch 479/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0284
# Epoch 480/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0283
# Epoch 481/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0282
# Epoch 482/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0282
# Epoch 483/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0281
# Epoch 484/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0280
# Epoch 485/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0279
# Epoch 486/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0279
# Epoch 487/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0278
# Epoch 488/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0277
# Epoch 489/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0277
# Epoch 490/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0276
# Epoch 491/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0275
# Epoch 492/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0274
# Epoch 493/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0274
# Epoch 494/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0273
# Epoch 495/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0272
# Epoch 496/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0272
# Epoch 497/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0271
# Epoch 498/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0270
# Epoch 499/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0270
# Epoch 500/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0269
# Epoch 501/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0268
# Epoch 502/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0268
# Epoch 503/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0267
# Epoch 504/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0266
# Epoch 505/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0266
# Epoch 506/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0265
# Epoch 507/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0264
# Epoch 508/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 1.0000 - loss: 0.0264
# Epoch 509/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0263
# Epoch 510/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0262
# Epoch 511/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0262
# Epoch 512/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0261
# Epoch 513/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0260
# Epoch 514/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0260
# Epoch 515/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0259
# Epoch 516/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0259
# Epoch 517/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0258
# Epoch 518/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0257
# Epoch 519/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0257
# Epoch 520/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0256
# Epoch 521/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0255
# Epoch 522/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0255
# Epoch 523/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0254
# Epoch 524/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0254
# Epoch 525/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0253
# Epoch 526/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0252
# Epoch 527/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0252
# Epoch 528/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0251
# Epoch 529/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0251
# Epoch 530/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0250
# Epoch 531/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0249
# Epoch 532/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0249
# Epoch 533/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0248
# Epoch 534/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0248
# Epoch 535/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 1.0000 - loss: 0.0247
# Epoch 536/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.0247
# Epoch 537/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0246
# Epoch 538/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0245
# Epoch 539/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0245
# Epoch 540/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 1.0000 - loss: 0.0244
# Epoch 541/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0244
# Epoch 542/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0243
# Epoch 543/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0243
# Epoch 544/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 1.0000 - loss: 0.0242
# Epoch 545/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.0241
# Epoch 546/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0241
# Epoch 547/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0240
# Epoch 548/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0240
# Epoch 549/1000
# ...
# Epoch 827/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0144
# Epoch 828/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0144
# Epoch 829/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0143
# Epoch 830/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0143
# Epoch 831/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0143
# Epoch 832/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0143
# Epoch 833/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 834/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 835/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 836/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 837/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0142
# Epoch 838/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 839/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 840/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 841/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 842/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0141
# Epoch 843/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 844/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 845/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 846/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 847/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0140
# Epoch 848/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 849/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 850/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 851/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 852/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0139
# Epoch 853/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 854/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 855/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 856/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 857/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 858/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0137
# Epoch 859/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0137
# Epoch 860/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0137
# Epoch 861/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0137
# Epoch 862/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0137
# Epoch 863/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 864/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 865/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 866/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 867/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0136
# Epoch 868/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 869/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 870/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 871/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 872/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0135
# Epoch 873/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 874/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 875/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 876/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 877/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0134
# Epoch 878/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 879/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 880/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 881/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 882/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0133
# Epoch 883/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 884/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 885/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 886/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 887/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 888/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0132
# Epoch 889/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 890/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 891/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 892/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 893/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0131
# Epoch 894/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 895/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 896/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 897/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 898/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 899/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0130
# Epoch 900/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 901/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 902/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 903/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 904/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 1.0000 - loss: 0.0129
# Epoch 905/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 906/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 907/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 908/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 909/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 910/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0128
# Epoch 911/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 912/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 913/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 914/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 915/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 916/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 917/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 918/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 919/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 920/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 921/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 922/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 1.0000 - loss: 0.0126
# Epoch 923/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 924/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 925/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 926/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 927/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 928/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0125
# Epoch 929/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 930/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 931/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 932/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 933/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 934/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 1.0000 - loss: 0.0124
# Epoch 935/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 936/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 937/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 938/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 939/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 940/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0123
# Epoch 941/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 942/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 943/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 944/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 945/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 946/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 0.0122
# Epoch 947/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 948/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 949/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 950/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 951/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 952/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0121
# Epoch 953/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 954/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 955/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 956/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 957/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 958/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0120
# Epoch 959/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 960/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 961/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 962/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 963/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 964/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 965/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 0.0119
# Epoch 966/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 967/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 968/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 969/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 970/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 971/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 972/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 973/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 974/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 975/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 976/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 977/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 978/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0117
# Epoch 979/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 980/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 981/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 982/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 983/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 984/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 985/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0116
# Epoch 986/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 987/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 988/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 989/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 990/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 991/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 992/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0115
# Epoch 993/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 994/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 995/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 996/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 997/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 998/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 999/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0114
# Epoch 1000/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 1.0000 - loss: 0.0113
#
# 모델 구조:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 20)             │           220 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │            42 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 264 (1.04 KB)
#  Trainable params: 262 (1.02 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
# 최종 손실값: 0.7149
# 최종 정확도: 0.6000

# %% [markdown]
# PyTorch를 이용한 LSTM 구현

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split

# 커스텀 데이터셋 클래스
class SequenceDataset(Dataset):
    def __init__(self, sequences, labels):
        self.sequences = sequences
        self.labels = labels

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        return self.sequences[idx], self.labels[idx]

# LSTM을 이용한 시퀀스 분류 모델
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=1):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        # LSTM 레이어
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)

        # 출력 레이어
        self.fc = nn.Linear(hidden_size, output_size)

        # 드롭아웃 레이어
        self.dropout = nn.Dropout(0.2)

    def forward(self, x):
        # 초기 은닉 상태와 셀 상태 설정
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        # LSTM 순전파
        out, _ = self.lstm(x, (h0, c0))

        # 드롭아웃 적용
        out = self.dropout(out[:, -1, :])

        # 출력 레이어 통과
        out = self.fc(out)
        return out

def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device):
    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        # 학습 모드
        model.train()
        train_loss = 0.0
        train_correct = 0
        train_total = 0

        for sequences, labels in train_loader:
            sequences, labels = sequences.to(device), labels.to(device)

            # 기울기 초기화
            optimizer.zero_grad()

            # 순전파
            outputs = model(sequences)
            loss = criterion(outputs, labels)

            # 역전파 및 최적화
            loss.backward()
            optimizer.step()

            # 통계 계산
            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()

        # 검증
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        all_preds = []
        all_labels = []

        with torch.no_grad():
            for sequences, labels in val_loader:
                sequences, labels = sequences.to(device), labels.to(device)
                outputs = model(sequences)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

                all_preds.extend(predicted.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())

        # 에포크별 결과 출력
        train_loss = train_loss / len(train_loader)
        train_acc = 100 * train_correct / train_total
        val_loss = val_loss / len(val_loader)
        val_acc = 100 * val_correct / val_total

        print(f'Epoch [{epoch+1}/{num_epochs}], '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, '
              f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%')

        # 최고 성능 모델 저장
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), 'best_model.pth')

    # 최종 평가 지표 계산
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='weighted')
    recall = recall_score(all_labels, all_preds, average='weighted')
    f1 = f1_score(all_labels, all_preds, average='weighted')

    print(f'\nFinal Evaluation Metrics:')
    print(f'Accuracy: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1 Score: {f1:.4f}')

def main():
    # 하이퍼파라미터 설정
    input_size = 10  # 입력 특성 차원
    hidden_size = 64  # 은닉 상태 차원
    output_size = 2  # 출력 클래스 수
    num_layers = 2
    batch_size = 32
    seq_length = 15
    num_epochs = 1000
    learning_rate = 0.001

    # 디바이스 설정
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # 가상의 데이터 생성
    num_samples = 1000
    sequences = torch.randn(num_samples, seq_length, input_size)
    labels = torch.randint(0, output_size, (num_samples,))

    # 데이터 분할
    X_train, X_val, y_train, y_val = train_test_split(
        sequences, labels, test_size=0.2, random_state=42
    )

    # 데이터로더 생성
    train_dataset = SequenceDataset(X_train, y_train)
    val_dataset = SequenceDataset(X_val, y_val)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)

    # 모델 생성
    model = LSTMModel(input_size, hidden_size, output_size, num_layers).to(device)

    # 손실 함수와 최적화기 설정
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # 모델 학습
    train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device)

# %%
main()
# Out:
# Epoch [1/1000], Train Loss: 0.6945, Train Acc: 49.88%, Val Loss: 0.6935, Val Acc: 51.50%
# Epoch [2/1000], Train Loss: 0.6939, Train Acc: 50.12%, Val Loss: 0.6935, Val Acc: 53.50%
# Epoch [3/1000], Train Loss: 0.6920, Train Acc: 53.12%, Val Loss: 0.6936, Val Acc: 53.00%
# Epoch [4/1000], Train Loss: 0.6901, Train Acc: 52.88%, Val Loss: 0.6951, Val Acc: 48.00%
# Epoch [5/1000], Train Loss: 0.6896, Train Acc: 53.12%, Val Loss: 0.6953, Val Acc: 52.00%
# Epoch [6/1000], Train Loss: 0.6847, Train Acc: 54.00%, Val Loss: 0.6993, Val Acc: 47.00%
# Epoch [7/1000], Train Loss: 0.6810, Train Acc: 55.62%, Val Loss: 0.7043, Val Acc: 50.00%
# Epoch [8/1000], Train Loss: 0.6728, Train Acc: 58.12%, Val Loss: 0.7193, Val Acc: 46.00%
# Epoch [9/1000], Train Loss: 0.6650, Train Acc: 58.38%, Val Loss: 0.7282, Val Acc: 46.50%
# Epoch [10/1000], Train Loss: 0.6571, Train Acc: 60.00%, Val Loss: 0.7205, Val Acc: 51.00%
# Epoch [11/1000], Train Loss: 0.6423, Train Acc: 61.88%, Val Loss: 0.7596, Val Acc: 47.50%
# Epoch [12/1000], Train Loss: 0.6355, Train Acc: 63.38%, Val Loss: 0.7485, Val Acc: 45.00%
# Epoch [13/1000], Train Loss: 0.6172, Train Acc: 65.00%, Val Loss: 0.7847, Val Acc: 46.00%
# Epoch [14/1000], Train Loss: 0.6058, Train Acc: 66.12%, Val Loss: 0.7825, Val Acc: 51.00%
# Epoch [15/1000], Train Loss: 0.5879, Train Acc: 68.62%, Val Loss: 0.8285, Val Acc: 50.50%
# Epoch [16/1000], Train Loss: 0.5482, Train Acc: 70.50%, Val Loss: 0.8935, Val Acc: 52.00%
# Epoch [17/1000], Train Loss: 0.5186, Train Acc: 73.25%, Val Loss: 0.8383, Val Acc: 50.00%
# Epoch [18/1000], Train Loss: 0.4846, Train Acc: 75.50%, Val Loss: 1.0199, Val Acc: 50.00%
# Epoch [19/1000], Train Loss: 0.4796, Train Acc: 77.00%, Val Loss: 0.9252, Val Acc: 48.00%
# Epoch [20/1000], Train Loss: 0.4398, Train Acc: 78.75%, Val Loss: 1.0355, Val Acc: 52.00%
# Epoch [21/1000], Train Loss: 0.3826, Train Acc: 81.62%, Val Loss: 1.1095, Val Acc: 50.00%
# Epoch [22/1000], Train Loss: 0.3245, Train Acc: 84.88%, Val Loss: 1.3213, Val Acc: 53.00%
# Epoch [23/1000], Train Loss: 0.3057, Train Acc: 87.25%, Val Loss: 1.3356, Val Acc: 53.00%
# Epoch [24/1000], Train Loss: 0.2804, Train Acc: 88.25%, Val Loss: 1.3420, Val Acc: 51.50%
# Epoch [25/1000], Train Loss: 0.2795, Train Acc: 88.50%, Val Loss: 1.4116, Val Acc: 51.00%
# Epoch [26/1000], Train Loss: 0.2211, Train Acc: 90.88%, Val Loss: 1.3799, Val Acc: 53.50%
# Epoch [27/1000], Train Loss: 0.2379, Train Acc: 90.38%, Val Loss: 1.6162, Val Acc: 50.00%
# Epoch [28/1000], Train Loss: 0.1624, Train Acc: 93.75%, Val Loss: 1.9264, Val Acc: 52.00%
# Epoch [29/1000], Train Loss: 0.1059, Train Acc: 96.62%, Val Loss: 2.0883, Val Acc: 50.50%
# Epoch [30/1000], Train Loss: 0.1039, Train Acc: 96.38%, Val Loss: 2.1709, Val Acc: 48.00%
# Epoch [31/1000], Train Loss: 0.0952, Train Acc: 96.62%, Val Loss: 2.1907, Val Acc: 50.00%
# Epoch [32/1000], Train Loss: 0.0647, Train Acc: 98.38%, Val Loss: 2.5347, Val Acc: 52.50%
# Epoch [33/1000], Train Loss: 0.0409, Train Acc: 98.88%, Val Loss: 2.7662, Val Acc: 49.50%
# Epoch [34/1000], Train Loss: 0.0280, Train Acc: 99.25%, Val Loss: 2.7526, Val Acc: 51.00%
# Epoch [35/1000], Train Loss: 0.0185, Train Acc: 99.75%, Val Loss: 2.8551, Val Acc: 50.00%
# Epoch [36/1000], Train Loss: 0.0299, Train Acc: 99.50%, Val Loss: 2.6523, Val Acc: 52.00%
# Epoch [37/1000], Train Loss: 0.0892, Train Acc: 96.50%, Val Loss: 2.6980, Val Acc: 52.50%
# Epoch [38/1000], Train Loss: 0.0563, Train Acc: 98.12%, Val Loss: 2.7722, Val Acc: 51.00%
# Epoch [39/1000], Train Loss: 0.0943, Train Acc: 97.25%, Val Loss: 2.5504, Val Acc: 44.50%
# Epoch [40/1000], Train Loss: 0.0624, Train Acc: 98.25%, Val Loss: 2.6213, Val Acc: 50.00%
# Epoch [41/1000], Train Loss: 0.0238, Train Acc: 99.62%, Val Loss: 2.8017, Val Acc: 50.00%
# Epoch [42/1000], Train Loss: 0.0143, Train Acc: 99.75%, Val Loss: 2.9733, Val Acc: 50.50%
# Epoch [43/1000], Train Loss: 0.0062, Train Acc: 100.00%, Val Loss: 3.0902, Val Acc: 52.00%
# Epoch [44/1000], Train Loss: 0.0034, Train Acc: 100.00%, Val Loss: 3.1729, Val Acc: 50.00%
# Epoch [45/1000], Train Loss: 0.0028, Train Acc: 100.00%, Val Loss: 3.2444, Val Acc: 50.50%
# Epoch [46/1000], Train Loss: 0.0021, Train Acc: 100.00%, Val Loss: 3.2846, Val Acc: 50.50%
# Epoch [47/1000], Train Loss: 0.0020, Train Acc: 100.00%, Val Loss: 3.3257, Val Acc: 51.00%
# Epoch [48/1000], Train Loss: 0.0016, Train Acc: 100.00%, Val Loss: 3.3737, Val Acc: 51.00%
# Epoch [49/1000], Train Loss: 0.0014, Train Acc: 100.00%, Val Loss: 3.4086, Val Acc: 51.00%
# Epoch [50/1000], Train Loss: 0.0013, Train Acc: 100.00%, Val Loss: 3.4350, Val Acc: 50.50%
# Epoch [51/1000], Train Loss: 0.0010, Train Acc: 100.00%, Val Loss: 3.4503, Val Acc: 50.00%
# Epoch [52/1000], Train Loss: 0.0011, Train Acc: 100.00%, Val Loss: 3.4801, Val Acc: 50.00%
# Epoch [53/1000], Train Loss: 0.0010, Train Acc: 100.00%, Val Loss: 3.5154, Val Acc: 49.50%
# Epoch [54/1000], Train Loss: 0.0009, Train Acc: 100.00%, Val Loss: 3.5311, Val Acc: 49.50%
# Epoch [55/1000], Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 3.5558, Val Acc: 50.00%
# Epoch [56/1000], Train Loss: 0.0008, Train Acc: 100.00%, Val Loss: 3.5756, Val Acc: 50.00%
# Epoch [57/1000], Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 3.5987, Val Acc: 49.50%
# Epoch [58/1000], Train Loss: 0.0007, Train Acc: 100.00%, Val Loss: 3.6188, Val Acc: 49.50%
# Epoch [59/1000], Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 3.6419, Val Acc: 49.00%
# Epoch [60/1000], Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 3.6599, Val Acc: 49.00%
# Epoch [61/1000], Train Loss: 0.0006, Train Acc: 100.00%, Val Loss: 3.6766, Val Acc: 49.00%
# Epoch [62/1000], Train Loss: 0.0005, Train Acc: 100.00%, Val Loss: 3.6984, Val Acc: 49.00%
# Epoch [63/1000], Train Loss: 0.0005, Train Acc: 100.00%, Val Loss: 3.7146, Val Acc: 49.00%
# Epoch [64/1000], Train Loss: 0.0004, Train Acc: 100.00%, Val Loss: 3.7400, Val Acc: 49.50%
# Epoch [65/1000], Train Loss: 0.0005, Train Acc: 100.00%, Val Loss: 3.7660, Val Acc: 49.00%
# Epoch [66/1000], Train Loss: 0.0004, Train Acc: 100.00%, Val Loss: 3.7850, Val Acc: 49.50%
# Epoch [67/1000], Train Loss: 0.0005, Train Acc: 100.00%, Val Loss: 3.7958, Val Acc: 49.00%
# Epoch [68/1000], Train Loss: 0.0005, Train Acc: 100.00%, Val Loss: 3.8102, Val Acc: 49.00%
# Epoch [69/1000], Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 3.8137, Val Acc: 48.00%
# Epoch [70/1000], Train Loss: 0.0004, Train Acc: 100.00%, Val Loss: 3.8372, Val Acc: 49.00%
# Epoch [71/1000], Train Loss: 0.0004, Train Acc: 100.00%, Val Loss: 3.8523, Val Acc: 47.50%
# Epoch [72/1000], Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 3.8561, Val Acc: 48.00%
# Epoch [73/1000], Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 3.8723, Val Acc: 48.00%
# Epoch [74/1000], Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 3.8821, Val Acc: 48.00%
# Epoch [75/1000], Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 3.8947, Val Acc: 48.50%
# Epoch [76/1000], Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 3.9102, Val Acc: 48.00%
# Epoch [77/1000], Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 3.9189, Val Acc: 48.00%
# Epoch [78/1000], Train Loss: 0.0003, Train Acc: 100.00%, Val Loss: 3.9435, Val Acc: 48.00%
# Epoch [79/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 3.9619, Val Acc: 47.50%
# Epoch [80/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 3.9668, Val Acc: 48.00%
# Epoch [81/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 3.9738, Val Acc: 48.00%
# Epoch [82/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 3.9830, Val Acc: 48.00%
# Epoch [83/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.0004, Val Acc: 48.00%
# Epoch [84/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.0083, Val Acc: 48.50%
# Epoch [85/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.0147, Val Acc: 48.50%
# Epoch [86/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.0276, Val Acc: 48.00%
# Epoch [87/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.0370, Val Acc: 48.00%
# Epoch [88/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.0562, Val Acc: 48.00%
# Epoch [89/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.0614, Val Acc: 48.00%
# Epoch [90/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.0617, Val Acc: 48.00%
# Epoch [91/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.0674, Val Acc: 48.00%
# Epoch [92/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.0796, Val Acc: 48.00%
# Epoch [93/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.0971, Val Acc: 48.00%
# Epoch [94/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.1046, Val Acc: 48.00%
# Epoch [95/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.1114, Val Acc: 48.00%
# Epoch [96/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.1289, Val Acc: 48.00%
# Epoch [97/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.1383, Val Acc: 48.00%
# Epoch [98/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.1430, Val Acc: 48.00%
# Epoch [99/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.1478, Val Acc: 48.00%
# Epoch [100/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.1576, Val Acc: 48.00%
# Epoch [101/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.1700, Val Acc: 48.00%
# Epoch [102/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.1818, Val Acc: 48.00%
# Epoch [103/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.1940, Val Acc: 48.00%
# Epoch [104/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2044, Val Acc: 48.00%
# Epoch [105/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2075, Val Acc: 48.00%
# Epoch [106/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2117, Val Acc: 48.00%
# Epoch [107/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2214, Val Acc: 48.50%
# Epoch [108/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2299, Val Acc: 48.50%
# Epoch [109/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2422, Val Acc: 48.00%
# Epoch [110/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2545, Val Acc: 48.00%
# Epoch [111/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2664, Val Acc: 48.00%
# Epoch [112/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2758, Val Acc: 48.00%
# Epoch [113/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2865, Val Acc: 48.00%
# Epoch [114/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3010, Val Acc: 48.00%
# Epoch [115/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3103, Val Acc: 48.00%
# Epoch [116/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3143, Val Acc: 48.00%
# Epoch [117/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2965, Val Acc: 48.50%
# Epoch [118/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.2941, Val Acc: 48.50%
# Epoch [119/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3023, Val Acc: 48.00%
# Epoch [120/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3130, Val Acc: 48.50%
# Epoch [121/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3162, Val Acc: 48.50%
# Epoch [122/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3261, Val Acc: 48.50%
# Epoch [123/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3364, Val Acc: 48.50%
# Epoch [124/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3447, Val Acc: 48.50%
# Epoch [125/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3540, Val Acc: 48.50%
# Epoch [126/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3668, Val Acc: 48.00%
# Epoch [127/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3866, Val Acc: 48.00%
# Epoch [128/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.3952, Val Acc: 48.00%
# Epoch [129/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4023, Val Acc: 48.00%
# Epoch [130/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4126, Val Acc: 48.00%
# Epoch [131/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4251, Val Acc: 48.00%
# Epoch [132/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4345, Val Acc: 48.00%
# Epoch [133/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4359, Val Acc: 48.00%
# Epoch [134/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4411, Val Acc: 48.00%
# Epoch [135/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4410, Val Acc: 48.50%
# Epoch [136/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4535, Val Acc: 48.50%
# Epoch [137/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4563, Val Acc: 48.50%
# Epoch [138/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4617, Val Acc: 48.50%
# Epoch [139/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4671, Val Acc: 48.50%
# Epoch [140/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4726, Val Acc: 48.50%
# Epoch [141/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4806, Val Acc: 48.00%
# Epoch [142/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4862, Val Acc: 48.00%
# Epoch [143/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.4988, Val Acc: 48.00%
# Epoch [144/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.5101, Val Acc: 48.00%
# Epoch [145/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.5154, Val Acc: 48.00%
# Epoch [146/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.5227, Val Acc: 48.00%
# Epoch [147/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.5365, Val Acc: 48.00%
# Epoch [148/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.5441, Val Acc: 48.00%
# Epoch [149/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.5507, Val Acc: 48.50%
# Epoch [150/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.5553, Val Acc: 48.50%
# Epoch [151/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.5594, Val Acc: 48.50%
# Epoch [152/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.5651, Val Acc: 48.50%
# Epoch [153/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.5715, Val Acc: 48.50%
# Epoch [154/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.5819, Val Acc: 48.50%
# Epoch [155/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.5941, Val Acc: 48.50%
# Epoch [156/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6023, Val Acc: 48.50%
# Epoch [157/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.6033, Val Acc: 48.50%
# Epoch [158/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6061, Val Acc: 49.00%
# Epoch [159/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6108, Val Acc: 49.00%
# Epoch [160/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.6295, Val Acc: 48.50%
# Epoch [161/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6409, Val Acc: 48.50%
# Epoch [162/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6470, Val Acc: 48.50%
# Epoch [163/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6460, Val Acc: 48.50%
# Epoch [164/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6499, Val Acc: 48.50%
# Epoch [165/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6609, Val Acc: 48.50%
# Epoch [166/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6753, Val Acc: 48.50%
# Epoch [167/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6734, Val Acc: 48.50%
# Epoch [168/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6767, Val Acc: 48.00%
# Epoch [169/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6834, Val Acc: 48.00%
# Epoch [170/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6918, Val Acc: 48.00%
# Epoch [171/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6966, Val Acc: 48.00%
# Epoch [172/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.6991, Val Acc: 48.00%
# Epoch [173/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7124, Val Acc: 48.50%
# Epoch [174/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7164, Val Acc: 48.50%
# Epoch [175/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7226, Val Acc: 48.50%
# Epoch [176/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7269, Val Acc: 48.50%
# Epoch [177/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7282, Val Acc: 48.50%
# Epoch [178/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7405, Val Acc: 48.50%
# Epoch [179/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7502, Val Acc: 48.50%
# Epoch [180/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7459, Val Acc: 48.50%
# Epoch [181/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7491, Val Acc: 48.50%
# Epoch [182/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7569, Val Acc: 48.50%
# Epoch [183/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7668, Val Acc: 48.50%
# Epoch [184/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7731, Val Acc: 48.50%
# Epoch [185/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7779, Val Acc: 48.50%
# Epoch [186/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7824, Val Acc: 48.50%
# Epoch [187/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.7976, Val Acc: 48.50%
# Epoch [188/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8047, Val Acc: 48.50%
# Epoch [189/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8095, Val Acc: 48.50%
# Epoch [190/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8135, Val Acc: 48.50%
# Epoch [191/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8194, Val Acc: 48.50%
# Epoch [192/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8174, Val Acc: 49.00%
# Epoch [193/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8175, Val Acc: 49.00%
# Epoch [194/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8242, Val Acc: 49.00%
# Epoch [195/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8343, Val Acc: 48.50%
# Epoch [196/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8399, Val Acc: 49.00%
# Epoch [197/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8494, Val Acc: 49.00%
# Epoch [198/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8580, Val Acc: 49.00%
# Epoch [199/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8704, Val Acc: 48.50%
# Epoch [200/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8793, Val Acc: 48.00%
# Epoch [201/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8809, Val Acc: 48.00%
# Epoch [202/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8835, Val Acc: 48.00%
# Epoch [203/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.8926, Val Acc: 48.00%
# Epoch [204/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9050, Val Acc: 48.00%
# Epoch [205/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9124, Val Acc: 48.00%
# Epoch [206/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9159, Val Acc: 48.50%
# Epoch [207/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9172, Val Acc: 48.50%
# Epoch [208/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9274, Val Acc: 48.50%
# Epoch [209/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9379, Val Acc: 48.50%
# Epoch [210/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9429, Val Acc: 48.50%
# Epoch [211/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9498, Val Acc: 48.50%
# Epoch [212/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9558, Val Acc: 48.50%
# Epoch [213/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9563, Val Acc: 48.50%
# Epoch [214/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9688, Val Acc: 48.50%
# Epoch [215/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9710, Val Acc: 48.50%
# Epoch [216/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9868, Val Acc: 48.50%
# Epoch [217/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 4.9996, Val Acc: 48.50%
# Epoch [218/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0022, Val Acc: 48.50%
# Epoch [219/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0071, Val Acc: 48.50%
# Epoch [220/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0206, Val Acc: 48.50%
# Epoch [221/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0221, Val Acc: 48.50%
# Epoch [222/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0192, Val Acc: 48.50%
# Epoch [223/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0243, Val Acc: 48.50%
# Epoch [224/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0266, Val Acc: 48.50%
# Epoch [225/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0353, Val Acc: 48.50%
# Epoch [226/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0429, Val Acc: 48.50%
# Epoch [227/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0506, Val Acc: 48.50%
# Epoch [228/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0522, Val Acc: 48.50%
# Epoch [229/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0536, Val Acc: 48.00%
# Epoch [230/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0579, Val Acc: 48.00%
# Epoch [231/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0666, Val Acc: 48.50%
# Epoch [232/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0696, Val Acc: 48.50%
# Epoch [233/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0838, Val Acc: 48.00%
# Epoch [234/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0866, Val Acc: 48.00%
# Epoch [235/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0831, Val Acc: 48.00%
# Epoch [236/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0938, Val Acc: 48.00%
# Epoch [237/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1032, Val Acc: 48.00%
# Epoch [238/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1014, Val Acc: 48.00%
# Epoch [239/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.0985, Val Acc: 48.00%
# Epoch [240/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1069, Val Acc: 48.00%
# Epoch [241/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1055, Val Acc: 48.00%
# Epoch [242/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1149, Val Acc: 48.00%
# Epoch [243/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1264, Val Acc: 48.00%
# Epoch [244/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1337, Val Acc: 48.00%
# Epoch [245/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1416, Val Acc: 48.00%
# Epoch [246/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1465, Val Acc: 48.00%
# Epoch [247/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1502, Val Acc: 48.00%
# Epoch [248/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1659, Val Acc: 48.00%
# Epoch [249/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1758, Val Acc: 48.00%
# Epoch [250/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1828, Val Acc: 48.00%
# Epoch [251/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1906, Val Acc: 48.00%
# Epoch [252/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1987, Val Acc: 48.00%
# Epoch [253/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1994, Val Acc: 48.00%
# Epoch [254/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2008, Val Acc: 48.00%
# Epoch [255/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2151, Val Acc: 48.00%
# Epoch [256/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2140, Val Acc: 48.00%
# Epoch [257/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2166, Val Acc: 48.00%
# Epoch [258/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2291, Val Acc: 48.00%
# Epoch [259/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2323, Val Acc: 48.00%
# Epoch [260/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2394, Val Acc: 48.00%
# Epoch [261/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2401, Val Acc: 48.00%
# Epoch [262/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2412, Val Acc: 48.00%
# Epoch [263/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2534, Val Acc: 48.00%
# Epoch [264/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2661, Val Acc: 48.00%
# Epoch [265/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2726, Val Acc: 48.00%
# Epoch [266/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2709, Val Acc: 48.00%
# Epoch [267/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2759, Val Acc: 48.00%
# Epoch [268/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2746, Val Acc: 48.00%
# Epoch [269/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2834, Val Acc: 48.00%
# Epoch [270/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3011, Val Acc: 48.00%
# Epoch [271/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2945, Val Acc: 48.00%
# Epoch [272/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2953, Val Acc: 48.00%
# Epoch [273/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3044, Val Acc: 48.00%
# Epoch [274/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3142, Val Acc: 48.00%
# Epoch [275/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3194, Val Acc: 48.00%
# Epoch [276/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3294, Val Acc: 48.00%
# Epoch [277/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3287, Val Acc: 48.00%
# Epoch [278/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3275, Val Acc: 48.00%
# Epoch [279/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3393, Val Acc: 48.00%
# Epoch [280/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3543, Val Acc: 48.00%
# Epoch [281/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3572, Val Acc: 48.00%
# Epoch [282/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3576, Val Acc: 48.00%
# Epoch [283/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3571, Val Acc: 48.00%
# Epoch [284/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3652, Val Acc: 48.00%
# Epoch [285/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3759, Val Acc: 48.00%
# Epoch [286/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3861, Val Acc: 48.00%
# Epoch [287/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3877, Val Acc: 48.00%
# Epoch [288/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3951, Val Acc: 48.00%
# Epoch [289/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4008, Val Acc: 48.00%
# Epoch [290/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4095, Val Acc: 48.00%
# Epoch [291/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4110, Val Acc: 48.00%
# Epoch [292/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4171, Val Acc: 48.00%
# Epoch [293/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4246, Val Acc: 48.00%
# Epoch [294/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4210, Val Acc: 48.00%
# Epoch [295/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4298, Val Acc: 48.00%
# Epoch [296/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4389, Val Acc: 48.00%
# Epoch [297/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4445, Val Acc: 48.00%
# Epoch [298/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4635, Val Acc: 48.50%
# Epoch [299/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4610, Val Acc: 48.50%
# Epoch [300/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4603, Val Acc: 48.50%
# Epoch [301/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4620, Val Acc: 48.50%
# Epoch [302/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4716, Val Acc: 48.50%
# Epoch [303/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4710, Val Acc: 48.50%
# Epoch [304/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4754, Val Acc: 48.00%
# Epoch [305/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4889, Val Acc: 48.50%
# Epoch [306/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4973, Val Acc: 48.00%
# Epoch [307/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4990, Val Acc: 48.00%
# Epoch [308/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5049, Val Acc: 48.00%
# Epoch [309/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5062, Val Acc: 48.00%
# Epoch [310/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5167, Val Acc: 48.00%
# Epoch [311/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5213, Val Acc: 48.00%
# Epoch [312/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5244, Val Acc: 48.00%
# Epoch [313/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5261, Val Acc: 48.00%
# Epoch [314/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5328, Val Acc: 48.50%
# Epoch [315/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5438, Val Acc: 48.50%
# Epoch [316/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5478, Val Acc: 48.50%
# Epoch [317/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5550, Val Acc: 48.50%
# Epoch [318/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5698, Val Acc: 48.50%
# Epoch [319/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5715, Val Acc: 48.00%
# Epoch [320/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5753, Val Acc: 48.00%
# Epoch [321/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5871, Val Acc: 48.00%
# Epoch [322/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5889, Val Acc: 48.00%
# Epoch [323/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5958, Val Acc: 48.50%
# Epoch [324/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5916, Val Acc: 48.50%
# Epoch [325/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5956, Val Acc: 48.50%
# Epoch [326/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5898, Val Acc: 49.00%
# Epoch [327/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6014, Val Acc: 48.50%
# Epoch [328/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5941, Val Acc: 49.00%
# Epoch [329/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5970, Val Acc: 49.00%
# Epoch [330/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6133, Val Acc: 48.50%
# Epoch [331/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6099, Val Acc: 49.00%
# Epoch [332/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6177, Val Acc: 49.00%
# Epoch [333/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6319, Val Acc: 48.50%
# Epoch [334/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6490, Val Acc: 48.50%
# Epoch [335/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6550, Val Acc: 48.50%
# Epoch [336/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6507, Val Acc: 48.00%
# Epoch [337/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6582, Val Acc: 48.50%
# Epoch [338/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6667, Val Acc: 48.00%
# Epoch [339/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6816, Val Acc: 48.50%
# Epoch [340/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6961, Val Acc: 48.50%
# Epoch [341/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7170, Val Acc: 48.50%
# Epoch [342/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7157, Val Acc: 48.50%
# Epoch [343/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6918, Val Acc: 48.50%
# Epoch [344/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7014, Val Acc: 48.00%
# Epoch [345/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7148, Val Acc: 47.50%
# Epoch [346/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7272, Val Acc: 48.00%
# Epoch [347/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7265, Val Acc: 48.00%
# Epoch [348/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7360, Val Acc: 48.00%
# Epoch [349/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7467, Val Acc: 48.50%
# Epoch [350/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7485, Val Acc: 48.50%
# Epoch [351/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7569, Val Acc: 48.50%
# Epoch [352/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7679, Val Acc: 48.50%
# Epoch [353/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7699, Val Acc: 48.50%
# Epoch [354/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7811, Val Acc: 48.50%
# Epoch [355/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7939, Val Acc: 48.50%
# Epoch [356/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7829, Val Acc: 48.50%
# Epoch [357/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7884, Val Acc: 48.50%
# Epoch [358/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8027, Val Acc: 48.50%
# Epoch [359/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8203, Val Acc: 48.50%
# Epoch [360/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8229, Val Acc: 48.50%
# Epoch [361/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8220, Val Acc: 48.50%
# Epoch [362/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8223, Val Acc: 48.50%
# Epoch [363/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8299, Val Acc: 48.50%
# Epoch [364/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8487, Val Acc: 48.50%
# Epoch [365/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8605, Val Acc: 48.50%
# Epoch [366/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8615, Val Acc: 48.50%
# Epoch [367/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8636, Val Acc: 48.50%
# Epoch [368/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8687, Val Acc: 48.50%
# Epoch [369/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8720, Val Acc: 48.00%
# Epoch [370/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8695, Val Acc: 48.00%
# Epoch [371/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8796, Val Acc: 48.50%
# Epoch [372/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8788, Val Acc: 48.50%
# Epoch [373/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8794, Val Acc: 48.50%
# Epoch [374/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8774, Val Acc: 48.50%
# Epoch [375/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8835, Val Acc: 48.50%
# Epoch [376/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8687, Val Acc: 48.50%
# Epoch [377/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8807, Val Acc: 48.50%
# Epoch [378/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8924, Val Acc: 48.50%
# Epoch [379/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.9180, Val Acc: 48.50%
# Epoch [380/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.9362, Val Acc: 48.50%
# Epoch [381/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.9323, Val Acc: 48.50%
# Epoch [382/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.9365, Val Acc: 48.50%
# Epoch [383/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.9401, Val Acc: 48.50%
# Epoch [384/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.9373, Val Acc: 48.50%
# Epoch [385/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.9437, Val Acc: 48.50%
# Epoch [386/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.9484, Val Acc: 48.50%
# Epoch [387/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.9523, Val Acc: 48.50%
# Epoch [388/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.9624, Val Acc: 48.00%
# Epoch [389/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.9640, Val Acc: 48.00%
# Epoch [390/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0039, Val Acc: 47.50%
# Epoch [391/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0142, Val Acc: 48.00%
# Epoch [392/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0093, Val Acc: 48.00%
# Epoch [393/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0095, Val Acc: 47.50%
# Epoch [394/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0125, Val Acc: 48.00%
# Epoch [395/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0201, Val Acc: 48.00%
# Epoch [396/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0207, Val Acc: 48.50%
# Epoch [397/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0289, Val Acc: 48.50%
# Epoch [398/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0348, Val Acc: 48.50%
# Epoch [399/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0371, Val Acc: 48.50%
# Epoch [400/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0422, Val Acc: 48.50%
# Epoch [401/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0458, Val Acc: 48.50%
# Epoch [402/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0654, Val Acc: 48.50%
# Epoch [403/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0662, Val Acc: 48.50%
# Epoch [404/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0609, Val Acc: 48.50%
# Epoch [405/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0784, Val Acc: 48.50%
# Epoch [406/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0761, Val Acc: 48.50%
# Epoch [407/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0719, Val Acc: 48.50%
# Epoch [408/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0784, Val Acc: 48.50%
# Epoch [409/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0874, Val Acc: 48.50%
# Epoch [410/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0999, Val Acc: 48.50%
# Epoch [411/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0926, Val Acc: 48.50%
# Epoch [412/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.0973, Val Acc: 48.50%
# Epoch [413/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1117, Val Acc: 48.50%
# Epoch [414/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1211, Val Acc: 48.50%
# Epoch [415/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1205, Val Acc: 48.50%
# Epoch [416/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1191, Val Acc: 48.50%
# Epoch [417/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1134, Val Acc: 48.50%
# Epoch [418/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1305, Val Acc: 48.50%
# Epoch [419/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1373, Val Acc: 48.50%
# Epoch [420/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1339, Val Acc: 48.50%
# Epoch [421/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1379, Val Acc: 48.50%
# Epoch [422/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1395, Val Acc: 48.50%
# Epoch [423/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1612, Val Acc: 49.00%
# Epoch [424/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1675, Val Acc: 49.00%
# Epoch [425/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1768, Val Acc: 49.00%
# Epoch [426/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1614, Val Acc: 49.00%
# Epoch [427/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1663, Val Acc: 49.00%
# Epoch [428/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1618, Val Acc: 48.50%
# Epoch [429/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1682, Val Acc: 48.50%
# Epoch [430/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1693, Val Acc: 48.50%
# Epoch [431/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1677, Val Acc: 49.00%
# Epoch [432/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1668, Val Acc: 49.50%
# Epoch [433/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.1960, Val Acc: 49.50%
# Epoch [434/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2100, Val Acc: 48.00%
# Epoch [435/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2143, Val Acc: 48.00%
# Epoch [436/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2191, Val Acc: 48.00%
# Epoch [437/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2146, Val Acc: 48.50%
# Epoch [438/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2240, Val Acc: 48.00%
# Epoch [439/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2369, Val Acc: 48.00%
# Epoch [440/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2503, Val Acc: 49.00%
# Epoch [441/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2478, Val Acc: 49.00%
# Epoch [442/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2512, Val Acc: 48.00%
# Epoch [443/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2492, Val Acc: 47.50%
# Epoch [444/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2548, Val Acc: 47.50%
# Epoch [445/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2512, Val Acc: 47.50%
# Epoch [446/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2593, Val Acc: 48.00%
# Epoch [447/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2657, Val Acc: 48.00%
# Epoch [448/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2683, Val Acc: 48.00%
# Epoch [449/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2774, Val Acc: 48.50%
# Epoch [450/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2937, Val Acc: 49.00%
# Epoch [451/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2933, Val Acc: 49.00%
# Epoch [452/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.2995, Val Acc: 49.00%
# Epoch [453/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3068, Val Acc: 49.00%
# Epoch [454/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3090, Val Acc: 48.50%
# Epoch [455/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3199, Val Acc: 48.50%
# Epoch [456/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3241, Val Acc: 48.50%
# Epoch [457/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3401, Val Acc: 48.50%
# Epoch [458/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3367, Val Acc: 48.50%
# Epoch [459/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3680, Val Acc: 49.00%
# Epoch [460/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3817, Val Acc: 49.00%
# Epoch [461/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3716, Val Acc: 48.50%
# Epoch [462/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3643, Val Acc: 48.50%
# Epoch [463/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3683, Val Acc: 48.50%
# Epoch [464/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.3964, Val Acc: 48.50%
# Epoch [465/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4067, Val Acc: 48.50%
# Epoch [466/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4091, Val Acc: 49.00%
# Epoch [467/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4154, Val Acc: 49.00%
# Epoch [468/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4108, Val Acc: 48.50%
# Epoch [469/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4050, Val Acc: 48.50%
# Epoch [470/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4167, Val Acc: 48.50%
# Epoch [471/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4342, Val Acc: 48.50%
# Epoch [472/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4201, Val Acc: 48.50%
# Epoch [473/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4134, Val Acc: 48.50%
# Epoch [474/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4029, Val Acc: 48.50%
# Epoch [475/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4172, Val Acc: 48.50%
# Epoch [476/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4370, Val Acc: 48.50%
# Epoch [477/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4317, Val Acc: 49.00%
# Epoch [478/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4367, Val Acc: 49.00%
# Epoch [479/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4479, Val Acc: 50.00%
# Epoch [480/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4520, Val Acc: 50.00%
# Epoch [481/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4534, Val Acc: 50.00%
# Epoch [482/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4705, Val Acc: 49.50%
# Epoch [483/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4819, Val Acc: 49.50%
# Epoch [484/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.4931, Val Acc: 49.50%
# Epoch [485/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5216, Val Acc: 49.50%
# Epoch [486/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5198, Val Acc: 49.50%
# Epoch [487/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5224, Val Acc: 50.00%
# Epoch [488/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5083, Val Acc: 50.50%
# Epoch [489/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5118, Val Acc: 50.00%
# Epoch [490/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5059, Val Acc: 50.00%
# Epoch [491/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5081, Val Acc: 49.50%
# Epoch [492/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5127, Val Acc: 49.50%
# Epoch [493/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5326, Val Acc: 50.00%
# Epoch [494/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5403, Val Acc: 49.50%
# Epoch [495/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5535, Val Acc: 49.50%
# Epoch [496/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5505, Val Acc: 49.50%
# Epoch [497/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5446, Val Acc: 49.50%
# Epoch [498/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5452, Val Acc: 49.50%
# Epoch [499/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5660, Val Acc: 50.00%
# Epoch [500/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5692, Val Acc: 50.50%
# Epoch [501/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5754, Val Acc: 50.50%
# Epoch [502/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5813, Val Acc: 50.50%
# Epoch [503/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5915, Val Acc: 49.50%
# Epoch [504/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5843, Val Acc: 49.50%
# Epoch [505/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5835, Val Acc: 49.50%
# Epoch [506/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5724, Val Acc: 50.00%
# Epoch [507/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.5922, Val Acc: 50.00%
# Epoch [508/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6143, Val Acc: 50.00%
# Epoch [509/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6124, Val Acc: 50.00%
# Epoch [510/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6034, Val Acc: 50.50%
# Epoch [511/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6198, Val Acc: 50.50%
# Epoch [512/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6072, Val Acc: 50.50%
# Epoch [513/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6270, Val Acc: 50.00%
# Epoch [514/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6384, Val Acc: 50.00%
# Epoch [515/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6345, Val Acc: 50.00%
# Epoch [516/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6340, Val Acc: 50.00%
# Epoch [517/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6344, Val Acc: 50.00%
# Epoch [518/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6584, Val Acc: 50.50%
# Epoch [519/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6743, Val Acc: 50.50%
# Epoch [520/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6745, Val Acc: 50.50%
# Epoch [521/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6785, Val Acc: 50.00%
# Epoch [522/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6828, Val Acc: 50.00%
# Epoch [523/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 6.6907, Val Acc: 50.00%
# ...
# Epoch [829/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.5561, Val Acc: 50.00%
# Epoch [830/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.5693, Val Acc: 50.00%
# Epoch [831/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.5823, Val Acc: 49.00%
# Epoch [832/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.5945, Val Acc: 49.50%
# Epoch [833/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.6047, Val Acc: 49.00%
# Epoch [834/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.6107, Val Acc: 49.50%
# Epoch [835/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.6181, Val Acc: 50.00%
# Epoch [836/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.6305, Val Acc: 49.50%
# Epoch [837/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.6388, Val Acc: 49.50%
# Epoch [838/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.6511, Val Acc: 49.00%
# Epoch [839/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.6641, Val Acc: 49.00%
# Epoch [840/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.6746, Val Acc: 49.00%
# Epoch [841/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.6861, Val Acc: 49.50%
# Epoch [842/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.6985, Val Acc: 49.50%
# Epoch [843/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.7089, Val Acc: 49.50%
# Epoch [844/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.7174, Val Acc: 49.50%
# Epoch [845/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.7263, Val Acc: 49.50%
# Epoch [846/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.7366, Val Acc: 49.50%
# Epoch [847/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.7487, Val Acc: 49.50%
# Epoch [848/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.7584, Val Acc: 50.00%
# Epoch [849/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.7647, Val Acc: 49.50%
# Epoch [850/1000], Train Loss: 0.0002, Train Acc: 100.00%, Val Loss: 4.7731, Val Acc: 50.00%
# Epoch [851/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.7813, Val Acc: 50.00%
# Epoch [852/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.7877, Val Acc: 50.00%
# Epoch [853/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.7887, Val Acc: 50.00%
# Epoch [854/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.7939, Val Acc: 50.00%
# Epoch [855/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8011, Val Acc: 50.00%
# Epoch [856/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8107, Val Acc: 50.50%
# Epoch [857/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8225, Val Acc: 50.00%
# Epoch [858/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8332, Val Acc: 49.50%
# Epoch [859/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8440, Val Acc: 49.50%
# Epoch [860/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8481, Val Acc: 49.50%
# Epoch [861/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8534, Val Acc: 49.50%
# Epoch [862/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8666, Val Acc: 49.50%
# Epoch [863/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8761, Val Acc: 49.50%
# Epoch [864/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8817, Val Acc: 49.50%
# Epoch [865/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8911, Val Acc: 49.00%
# Epoch [866/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.8969, Val Acc: 49.00%
# Epoch [867/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9098, Val Acc: 49.00%
# Epoch [868/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9204, Val Acc: 49.00%
# Epoch [869/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9284, Val Acc: 49.00%
# Epoch [870/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9375, Val Acc: 49.00%
# Epoch [871/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9449, Val Acc: 49.00%
# Epoch [872/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9526, Val Acc: 49.00%
# Epoch [873/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9608, Val Acc: 49.00%
# Epoch [874/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9647, Val Acc: 49.00%
# Epoch [875/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9737, Val Acc: 49.00%
# Epoch [876/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9806, Val Acc: 49.00%
# Epoch [877/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9891, Val Acc: 49.00%
# Epoch [878/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 4.9944, Val Acc: 49.00%
# Epoch [879/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.0044, Val Acc: 48.50%
# Epoch [880/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.0116, Val Acc: 48.50%
# Epoch [881/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.0191, Val Acc: 49.00%
# Epoch [882/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.0337, Val Acc: 49.00%
# Epoch [883/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.0416, Val Acc: 49.00%
# Epoch [884/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.0477, Val Acc: 49.00%
# Epoch [885/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.0526, Val Acc: 49.00%
# Epoch [886/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.0616, Val Acc: 49.00%
# Epoch [887/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.0709, Val Acc: 49.00%
# Epoch [888/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.0811, Val Acc: 49.00%
# Epoch [889/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.0908, Val Acc: 49.00%
# Epoch [890/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.1000, Val Acc: 49.00%
# Epoch [891/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1055, Val Acc: 49.00%
# Epoch [892/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.1093, Val Acc: 49.00%
# Epoch [893/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.1178, Val Acc: 49.00%
# Epoch [894/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.1229, Val Acc: 49.00%
# Epoch [895/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.1289, Val Acc: 49.00%
# Epoch [896/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1372, Val Acc: 49.00%
# Epoch [897/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.1464, Val Acc: 49.00%
# Epoch [898/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.1562, Val Acc: 49.00%
# Epoch [899/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1619, Val Acc: 49.00%
# Epoch [900/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1714, Val Acc: 49.00%
# Epoch [901/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.1788, Val Acc: 49.00%
# Epoch [902/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1826, Val Acc: 49.00%
# Epoch [903/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.1927, Val Acc: 49.00%
# Epoch [904/1000], Train Loss: 0.0001, Train Acc: 100.00%, Val Loss: 5.1978, Val Acc: 48.50%
# Epoch [905/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2098, Val Acc: 48.50%
# Epoch [906/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2171, Val Acc: 48.50%
# Epoch [907/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2233, Val Acc: 48.50%
# Epoch [908/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2319, Val Acc: 48.50%
# Epoch [909/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2397, Val Acc: 49.00%
# Epoch [910/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2469, Val Acc: 48.50%
# Epoch [911/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2525, Val Acc: 48.50%
# Epoch [912/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2617, Val Acc: 48.50%
# Epoch [913/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2716, Val Acc: 48.50%
# Epoch [914/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2778, Val Acc: 48.50%
# Epoch [915/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2829, Val Acc: 48.50%
# Epoch [916/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2906, Val Acc: 48.50%
# Epoch [917/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2942, Val Acc: 48.50%
# Epoch [918/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.2981, Val Acc: 48.50%
# Epoch [919/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3063, Val Acc: 48.50%
# Epoch [920/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3131, Val Acc: 48.50%
# Epoch [921/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3182, Val Acc: 48.50%
# Epoch [922/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3219, Val Acc: 48.50%
# Epoch [923/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3296, Val Acc: 48.50%
# Epoch [924/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3379, Val Acc: 48.50%
# Epoch [925/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3469, Val Acc: 48.50%
# Epoch [926/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3531, Val Acc: 48.50%
# Epoch [927/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3564, Val Acc: 48.50%
# Epoch [928/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3639, Val Acc: 48.50%
# Epoch [929/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3711, Val Acc: 48.50%
# Epoch [930/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3799, Val Acc: 48.50%
# Epoch [931/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3856, Val Acc: 48.50%
# Epoch [932/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3885, Val Acc: 48.50%
# Epoch [933/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.3922, Val Acc: 48.50%
# Epoch [934/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4046, Val Acc: 48.50%
# Epoch [935/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4112, Val Acc: 48.50%
# Epoch [936/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4186, Val Acc: 48.50%
# Epoch [937/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4254, Val Acc: 48.50%
# Epoch [938/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4313, Val Acc: 48.50%
# Epoch [939/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4373, Val Acc: 48.50%
# Epoch [940/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4451, Val Acc: 48.50%
# Epoch [941/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4493, Val Acc: 48.50%
# Epoch [942/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4536, Val Acc: 48.50%
# Epoch [943/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4602, Val Acc: 48.50%
# Epoch [944/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4652, Val Acc: 48.50%
# Epoch [945/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4730, Val Acc: 48.50%
# Epoch [946/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4793, Val Acc: 48.50%
# Epoch [947/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4892, Val Acc: 48.50%
# Epoch [948/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4944, Val Acc: 48.50%
# Epoch [949/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.4983, Val Acc: 48.50%
# Epoch [950/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5041, Val Acc: 48.50%
# Epoch [951/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5124, Val Acc: 48.50%
# Epoch [952/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5182, Val Acc: 48.50%
# Epoch [953/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5218, Val Acc: 48.50%
# Epoch [954/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5300, Val Acc: 48.50%
# Epoch [955/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5369, Val Acc: 48.50%
# Epoch [956/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5416, Val Acc: 48.50%
# Epoch [957/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5460, Val Acc: 48.50%
# Epoch [958/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5514, Val Acc: 48.50%
# Epoch [959/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5594, Val Acc: 48.50%
# Epoch [960/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5691, Val Acc: 48.50%
# Epoch [961/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5768, Val Acc: 48.50%
# Epoch [962/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5806, Val Acc: 48.50%
# Epoch [963/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5851, Val Acc: 48.50%
# Epoch [964/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5918, Val Acc: 48.50%
# Epoch [965/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.5984, Val Acc: 48.50%
# Epoch [966/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6054, Val Acc: 48.50%
# Epoch [967/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6122, Val Acc: 48.50%
# Epoch [968/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6183, Val Acc: 48.50%
# Epoch [969/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6227, Val Acc: 48.50%
# Epoch [970/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6281, Val Acc: 48.50%
# Epoch [971/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6344, Val Acc: 48.50%
# Epoch [972/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6423, Val Acc: 48.50%
# Epoch [973/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6493, Val Acc: 48.50%
# Epoch [974/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6561, Val Acc: 48.50%
# Epoch [975/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6613, Val Acc: 48.50%
# Epoch [976/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6687, Val Acc: 48.50%
# Epoch [977/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6802, Val Acc: 48.50%
# Epoch [978/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6845, Val Acc: 48.50%
# Epoch [979/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6892, Val Acc: 48.50%
# Epoch [980/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6916, Val Acc: 48.50%
# Epoch [981/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.6959, Val Acc: 48.50%
# Epoch [982/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7039, Val Acc: 48.50%
# Epoch [983/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7092, Val Acc: 48.50%
# Epoch [984/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7137, Val Acc: 48.50%
# Epoch [985/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7155, Val Acc: 48.50%
# Epoch [986/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7184, Val Acc: 48.50%
# Epoch [987/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7252, Val Acc: 48.50%
# Epoch [988/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7309, Val Acc: 48.50%
# Epoch [989/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7365, Val Acc: 48.50%
# Epoch [990/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7491, Val Acc: 48.50%
# Epoch [991/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7590, Val Acc: 48.50%
# Epoch [992/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7618, Val Acc: 48.50%
# Epoch [993/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7649, Val Acc: 48.50%
# Epoch [994/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7727, Val Acc: 48.50%
# Epoch [995/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7810, Val Acc: 48.50%
# Epoch [996/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7872, Val Acc: 48.50%
# Epoch [997/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.7968, Val Acc: 48.50%
# Epoch [998/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8087, Val Acc: 48.50%
# Epoch [999/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8138, Val Acc: 48.50%
# Epoch [1000/1000], Train Loss: 0.0000, Train Acc: 100.00%, Val Loss: 5.8173, Val Acc: 48.00%
#
# Final Evaluation Metrics:
# Accuracy: 0.4800
# Precision: 0.4869
# Recall: 0.4800
# F1 Score: 0.4811

# %% [markdown]
# tensorflow 이용 LSTM

# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split

# 1) 하이퍼파라미터 설정
input_size    = 10
hidden_size   = 64
output_size   = 2
num_layers    = 2
seq_length    = 15
batch_size    = 32
num_epochs    = 1000
learning_rate = 0.001

# 2) 가상 데이터 생성
num_samples = 1000
sequences = np.random.randn(num_samples, seq_length, input_size).astype(np.float32)
labels    = np.random.randint(0, output_size, size=(num_samples,)).astype(np.int32)

# 3) 학습/검증 데이터 분할
X_train, X_val, y_train, y_val = train_test_split(
    sequences, labels, test_size=0.2, random_state=42
)

# 4) tf.data.Dataset 생성 및 배치 처리
train_dataset = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .shuffle(buffer_size=1000)
    .batch(batch_size)
)
val_dataset = (
    tf.data.Dataset.from_tensor_slices((X_val, y_val))
    .batch(batch_size)
)

# 5) 모델 정의 (Sequential API + LSTM × num_layers + Dropout + Dense)
model = tf.keras.Sequential()
for i in range(num_layers):
    # 중간 LSTM 층은 return_sequences=True, 마지막 층은 False
    model.add(tf.keras.layers.LSTM(
        hidden_size,
        return_sequences=(i < num_layers - 1)
    ))
# PyTorch 코드의 self.dropout 과 유사하게, 마지막 타임스텝 출력에 Dropout 적용
model.add(tf.keras.layers.Dropout(0.2))
# 출력층 (logits 생성)
model.add(tf.keras.layers.Dense(output_size))

# 6) 모델 컴파일: 옵티마이저, 손실함수, 평가 지표 설정
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# 7) 체크포인트 콜백: 검증 손실이 가장 낮을 때만 best_model.h5로 저장
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
    'best_model.h5',
    save_best_only=True,
    monitor='val_loss',
    mode='min'
)

# 8) 모델 학습
history = model.fit(
    train_dataset,
    epochs=num_epochs,
    validation_data=val_dataset,
    callbacks=[checkpoint_cb]
)

# 9) 최적의 가중치 로드
model.load_weights('best_model.h5')

# 10) 최종 평가 지표 계산
#    검증 세트 전체에 대해 예측을 수행하고, sklearn으로 평가
y_pred_prob = model.predict(val_dataset)           # (num_val_samples, output_size)
y_pred      = np.argmax(y_pred_prob, axis=1)       # 클래스 레이블로 변환
y_true      = y_val                                # train_test_split으로부터 분할된 실제 레이블

accuracy  = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall    = recall_score(y_true, y_pred, average='weighted')
f1        = f1_score(y_true, y_pred, average='weighted')

print('\n최종 평가 지표:')
print(f'Accuracy:  {accuracy:.4f}')
print(f'Precision: {precision:.4f}')
print(f'Recall:    {recall:.4f}')
print(f'F1 Score:  {f1:.4f}')
# Out:
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.4903 - loss: 0.6951
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.4901 - loss: 0.6951 - val_accuracy: 0.4950 - val_loss: 0.6970
# Epoch 2/1000
# 24/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5658 - loss: 0.6853
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5650 - loss: 0.6855 - val_accuracy: 0.5350 - val_loss: 0.6940
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5485 - loss: 0.6811 - val_accuracy: 0.4950 - val_loss: 0.6949
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5745 - loss: 0.6794 - val_accuracy: 0.5000 - val_loss: 0.6993
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5808 - loss: 0.6694 - val_accuracy: 0.4900 - val_loss: 0.7034
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6033 - loss: 0.6677 - val_accuracy: 0.4950 - val_loss: 0.6987
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6063 - loss: 0.6713 - val_accuracy: 0.5200 - val_loss: 0.7131
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6009 - loss: 0.6496 - val_accuracy: 0.5450 - val_loss: 0.7376
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6562 - loss: 0.6150 - val_accuracy: 0.5700 - val_loss: 0.7500
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.6777 - loss: 0.5960 - val_accuracy: 0.5050 - val_loss: 0.8882
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7153 - loss: 0.5681 - val_accuracy: 0.5450 - val_loss: 0.8631
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7191 - loss: 0.5357 - val_accuracy: 0.5200 - val_loss: 0.8799
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7416 - loss: 0.5026 - val_accuracy: 0.5450 - val_loss: 1.0217
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7679 - loss: 0.4695 - val_accuracy: 0.5600 - val_loss: 1.1236
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7892 - loss: 0.4519 - val_accuracy: 0.5650 - val_loss: 1.0378
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8109 - loss: 0.4071 - val_accuracy: 0.5300 - val_loss: 1.0632
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8344 - loss: 0.3663 - val_accuracy: 0.5350 - val_loss: 1.0988
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8685 - loss: 0.3310 - val_accuracy: 0.5500 - val_loss: 1.2167
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8582 - loss: 0.3360 - val_accuracy: 0.5300 - val_loss: 1.2685
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8912 - loss: 0.2846 - val_accuracy: 0.5650 - val_loss: 1.5159
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8966 - loss: 0.2336 - val_accuracy: 0.5800 - val_loss: 1.3987
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9043 - loss: 0.2416 - val_accuracy: 0.6000 - val_loss: 1.6295
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9256 - loss: 0.1842 - val_accuracy: 0.5650 - val_loss: 1.6725
# Epoch 24/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9429 - loss: 0.1754 - val_accuracy: 0.5700 - val_loss: 1.8293
# Epoch 25/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9573 - loss: 0.1143 - val_accuracy: 0.5650 - val_loss: 1.9417
# Epoch 26/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9686 - loss: 0.1106 - val_accuracy: 0.5800 - val_loss: 2.0275
# Epoch 27/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9613 - loss: 0.1017 - val_accuracy: 0.5350 - val_loss: 2.2220
# Epoch 28/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9372 - loss: 0.1725 - val_accuracy: 0.5750 - val_loss: 1.9500
# Epoch 29/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9423 - loss: 0.1463 - val_accuracy: 0.5600 - val_loss: 2.0026
# Epoch 30/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9823 - loss: 0.0818 - val_accuracy: 0.5300 - val_loss: 2.1193
# Epoch 31/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9879 - loss: 0.0471 - val_accuracy: 0.5600 - val_loss: 2.3546
# Epoch 32/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9882 - loss: 0.0404 - val_accuracy: 0.5400 - val_loss: 2.5429
# Epoch 33/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9960 - loss: 0.0208 - val_accuracy: 0.5850 - val_loss: 2.6384
# Epoch 34/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9949 - loss: 0.0256 - val_accuracy: 0.5700 - val_loss: 2.7660
# Epoch 35/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9950 - loss: 0.0169 - val_accuracy: 0.5950 - val_loss: 2.8134
# Epoch 36/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9705 - loss: 0.1172 - val_accuracy: 0.5650 - val_loss: 2.7555
# Epoch 37/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9769 - loss: 0.0803 - val_accuracy: 0.5350 - val_loss: 2.3663
# Epoch 38/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9841 - loss: 0.0564 - val_accuracy: 0.5400 - val_loss: 2.5553
# Epoch 39/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9881 - loss: 0.0341 - val_accuracy: 0.5400 - val_loss: 2.7292
# Epoch 40/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9987 - loss: 0.0097 - val_accuracy: 0.5850 - val_loss: 2.7824
# Epoch 41/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.5850 - val_loss: 2.8727
# Epoch 42/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9991 - loss: 0.0088 - val_accuracy: 0.5650 - val_loss: 2.9488
# Epoch 43/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.5800 - val_loss: 2.9626
# Epoch 44/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9983 - loss: 0.0055 - val_accuracy: 0.5750 - val_loss: 3.0525
# Epoch 45/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5800 - val_loss: 3.1384
# Epoch 46/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.5750 - val_loss: 3.1851
# Epoch 47/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5700 - val_loss: 3.2274
# Epoch 48/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5650 - val_loss: 3.2665
# Epoch 49/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5650 - val_loss: 3.2924
# Epoch 50/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5550 - val_loss: 3.3234
# Epoch 51/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5550 - val_loss: 3.3596
# Epoch 52/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 9.9620e-04 - val_accuracy: 0.5550 - val_loss: 3.3808
# Epoch 53/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 8.3620e-04 - val_accuracy: 0.5550 - val_loss: 3.4079
# Epoch 54/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 7.9220e-04 - val_accuracy: 0.5550 - val_loss: 3.4320
# Epoch 55/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 8.5680e-04 - val_accuracy: 0.5650 - val_loss: 3.4619
# Epoch 56/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 9.2587e-04 - val_accuracy: 0.5600 - val_loss: 3.4827
# Epoch 57/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 8.3569e-04 - val_accuracy: 0.5600 - val_loss: 3.5048
# Epoch 58/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 5.4651e-04 - val_accuracy: 0.5600 - val_loss: 3.5264
# Epoch 59/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 6.2308e-04 - val_accuracy: 0.5600 - val_loss: 3.5524
# Epoch 60/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 6.1195e-04 - val_accuracy: 0.5600 - val_loss: 3.5627
# Epoch 61/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 5.3746e-04 - val_accuracy: 0.5600 - val_loss: 3.5758
# Epoch 62/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 4.4583e-04 - val_accuracy: 0.5600 - val_loss: 3.5943
# Epoch 63/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 5.1725e-04 - val_accuracy: 0.5600 - val_loss: 3.6129
# Epoch 64/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 4.2907e-04 - val_accuracy: 0.5650 - val_loss: 3.6264
# Epoch 65/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 4.1625e-04 - val_accuracy: 0.5650 - val_loss: 3.6444
# Epoch 66/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 4.9008e-04 - val_accuracy: 0.5650 - val_loss: 3.6566
# Epoch 67/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 4.1112e-04 - val_accuracy: 0.5650 - val_loss: 3.6720
# Epoch 68/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 3.4249e-04 - val_accuracy: 0.5650 - val_loss: 3.6893
# Epoch 69/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 4.0093e-04 - val_accuracy: 0.5600 - val_loss: 3.7019
# Epoch 70/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 4.5000e-04 - val_accuracy: 0.5600 - val_loss: 3.7081
# Epoch 71/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 3.1485e-04 - val_accuracy: 0.5600 - val_loss: 3.7249
# Epoch 72/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 2.8224e-04 - val_accuracy: 0.5600 - val_loss: 3.7410
# Epoch 73/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 2.9098e-04 - val_accuracy: 0.5650 - val_loss: 3.7553
# Epoch 74/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 3.4861e-04 - val_accuracy: 0.5650 - val_loss: 3.7702
# Epoch 75/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 3.3690e-04 - val_accuracy: 0.5650 - val_loss: 3.7842
# Epoch 76/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.9366e-04 - val_accuracy: 0.5650 - val_loss: 3.8025
# Epoch 77/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 2.1433e-04 - val_accuracy: 0.5650 - val_loss: 3.8104
# Epoch 78/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.8435e-04 - val_accuracy: 0.5650 - val_loss: 3.8137
# Epoch 79/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 2.2477e-04 - val_accuracy: 0.5650 - val_loss: 3.8243
# Epoch 80/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.4568e-04 - val_accuracy: 0.5650 - val_loss: 3.8331
# Epoch 81/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.6321e-04 - val_accuracy: 0.5650 - val_loss: 3.8432
# Epoch 82/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.5960e-04 - val_accuracy: 0.5700 - val_loss: 3.8512
# Epoch 83/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.8783e-04 - val_accuracy: 0.5700 - val_loss: 3.8593
# Epoch 84/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.3751e-04 - val_accuracy: 0.5700 - val_loss: 3.8703
# Epoch 85/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 1.9900e-04 - val_accuracy: 0.5650 - val_loss: 3.8818
# Epoch 86/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.4337e-04 - val_accuracy: 0.5750 - val_loss: 3.8951
# Epoch 87/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.8158e-04 - val_accuracy: 0.5700 - val_loss: 3.9009
# Epoch 88/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.6453e-04 - val_accuracy: 0.5700 - val_loss: 3.9080
# Epoch 89/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.9116e-04 - val_accuracy: 0.5700 - val_loss: 3.9190
# Epoch 90/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.2195e-04 - val_accuracy: 0.5650 - val_loss: 3.9308
# Epoch 91/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.4536e-04 - val_accuracy: 0.5700 - val_loss: 3.9415
# Epoch 92/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.3005e-04 - val_accuracy: 0.5700 - val_loss: 3.9504
# Epoch 93/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 1.3764e-04 - val_accuracy: 0.5650 - val_loss: 3.9552
# Epoch 94/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 1.5444e-04 - val_accuracy: 0.5700 - val_loss: 3.9615
# Epoch 95/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 1.0000 - loss: 1.5273e-04 - val_accuracy: 0.5600 - val_loss: 3.9686
# Epoch 96/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 1.4918e-04 - val_accuracy: 0.5650 - val_loss: 3.9808
# Epoch 97/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.3670e-04 - val_accuracy: 0.5650 - val_loss: 3.9913
# Epoch 98/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.2913e-04 - val_accuracy: 0.5650 - val_loss: 4.0010
# Epoch 99/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.4458e-04 - val_accuracy: 0.5650 - val_loss: 4.0135
# Epoch 100/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.1485e-04 - val_accuracy: 0.5700 - val_loss: 4.0225
# Epoch 101/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.5897e-04 - val_accuracy: 0.5650 - val_loss: 4.0279
# Epoch 102/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.2850e-04 - val_accuracy: 0.5650 - val_loss: 4.0443
# Epoch 103/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.1593e-04 - val_accuracy: 0.5700 - val_loss: 4.0587
# Epoch 104/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.3299e-04 - val_accuracy: 0.5700 - val_loss: 4.0649
# Epoch 105/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.2660e-04 - val_accuracy: 0.5700 - val_loss: 4.0775
# Epoch 106/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 9.2841e-05 - val_accuracy: 0.5650 - val_loss: 4.0861
# Epoch 107/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.1392e-04 - val_accuracy: 0.5650 - val_loss: 4.0951
# Epoch 108/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 9.3896e-05 - val_accuracy: 0.5650 - val_loss: 4.1038
# Epoch 109/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 1.0000 - loss: 8.2179e-05 - val_accuracy: 0.5650 - val_loss: 4.1079
# Epoch 110/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 1.0000 - loss: 9.4087e-05 - val_accuracy: 0.5700 - val_loss: 4.1168
# Epoch 111/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 8.8597e-05 - val_accuracy: 0.5700 - val_loss: 4.1259
# Epoch 112/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 9.0398e-05 - val_accuracy: 0.5650 - val_loss: 4.1352
# Epoch 113/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 9.4264e-05 - val_accuracy: 0.5650 - val_loss: 4.1439
# Epoch 114/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 7.6068e-05 - val_accuracy: 0.5650 - val_loss: 4.1511
# Epoch 115/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.1626e-04 - val_accuracy: 0.5700 - val_loss: 4.1590
# Epoch 116/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 1.0000 - loss: 7.3877e-05 - val_accuracy: 0.5700 - val_loss: 4.1632
# Epoch 117/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 9.2963e-05 - val_accuracy: 0.5700 - val_loss: 4.1693
# Epoch 118/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 6.6891e-05 - val_accuracy: 0.5700 - val_loss: 4.1737
# Epoch 119/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 8.5646e-05 - val_accuracy: 0.5700 - val_loss: 4.1788
# Epoch 120/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.0788e-04 - val_accuracy: 0.5700 - val_loss: 4.1854
# Epoch 121/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.1776e-04 - val_accuracy: 0.5700 - val_loss: 4.1946
# Epoch 122/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 6.3780e-05 - val_accuracy: 0.5700 - val_loss: 4.2073
# Epoch 123/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 8.6777e-05 - val_accuracy: 0.5700 - val_loss: 4.2165
# Epoch 124/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 6.3608e-05 - val_accuracy: 0.5700 - val_loss: 4.2242
# Epoch 125/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 7.4570e-05 - val_accuracy: 0.5700 - val_loss: 4.2339
# Epoch 126/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 5.4725e-05 - val_accuracy: 0.5700 - val_loss: 4.2356
# Epoch 127/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 5.8715e-05 - val_accuracy: 0.5700 - val_loss: 4.2412
# Epoch 128/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 6.2222e-05 - val_accuracy: 0.5700 - val_loss: 4.2446
# Epoch 129/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 5.5315e-05 - val_accuracy: 0.5700 - val_loss: 4.2503
# Epoch 130/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 1.1065e-04 - val_accuracy: 0.5700 - val_loss: 4.2596
# Epoch 131/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 5.1735e-05 - val_accuracy: 0.5700 - val_loss: 4.2655
# Epoch 132/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 5.2244e-05 - val_accuracy: 0.5700 - val_loss: 4.2752
# Epoch 133/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.7584e-05 - val_accuracy: 0.5700 - val_loss: 4.2821
# Epoch 134/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 6.8786e-05 - val_accuracy: 0.5700 - val_loss: 4.2936
# Epoch 135/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 4.3393e-05 - val_accuracy: 0.5700 - val_loss: 4.2976
# Epoch 136/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 5.5999e-05 - val_accuracy: 0.5700 - val_loss: 4.3078
# Epoch 137/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 4.2724e-05 - val_accuracy: 0.5700 - val_loss: 4.3177
# Epoch 138/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 4.6136e-05 - val_accuracy: 0.5700 - val_loss: 4.3252
# Epoch 139/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 3.9427e-05 - val_accuracy: 0.5700 - val_loss: 4.3290
# Epoch 140/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 5.9681e-05 - val_accuracy: 0.5700 - val_loss: 4.3363
# Epoch 141/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 6.8923e-05 - val_accuracy: 0.5700 - val_loss: 4.3402
# Epoch 142/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 4.5020e-05 - val_accuracy: 0.5700 - val_loss: 4.3455
# Epoch 143/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 5.5571e-05 - val_accuracy: 0.5700 - val_loss: 4.3516
# Epoch 144/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.0236e-05 - val_accuracy: 0.5700 - val_loss: 4.3566
# Epoch 145/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 4.0548e-05 - val_accuracy: 0.5700 - val_loss: 4.3618
# Epoch 146/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 4.9803e-05 - val_accuracy: 0.5700 - val_loss: 4.3585
# Epoch 147/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 6.4281e-05 - val_accuracy: 0.5750 - val_loss: 4.3645
# Epoch 148/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 4.0759e-05 - val_accuracy: 0.5750 - val_loss: 4.3726
# Epoch 149/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 4.1044e-05 - val_accuracy: 0.5750 - val_loss: 4.3793
# Epoch 150/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 1.0000 - loss: 4.0169e-05 - val_accuracy: 0.5750 - val_loss: 4.3873
# Epoch 151/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 4.3767e-05 - val_accuracy: 0.5750 - val_loss: 4.3916
# Epoch 152/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 3.7634e-05 - val_accuracy: 0.5750 - val_loss: 4.4000
# Epoch 153/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 3.8315e-05 - val_accuracy: 0.5750 - val_loss: 4.4103
# Epoch 154/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 6.0344e-05 - val_accuracy: 0.5750 - val_loss: 4.4181
# Epoch 155/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 3.6219e-05 - val_accuracy: 0.5750 - val_loss: 4.4222
# Epoch 156/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 3.0999e-05 - val_accuracy: 0.5750 - val_loss: 4.4234
# Epoch 157/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 3.5908e-05 - val_accuracy: 0.5750 - val_loss: 4.4276
# Epoch 158/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.9287e-05 - val_accuracy: 0.5750 - val_loss: 4.4313
# Epoch 159/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 3.1195e-05 - val_accuracy: 0.5750 - val_loss: 4.4371
# Epoch 160/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 3.8322e-05 - val_accuracy: 0.5750 - val_loss: 4.4467
# Epoch 161/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 4.9135e-05 - val_accuracy: 0.5700 - val_loss: 4.4526
# Epoch 162/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 1.0000 - loss: 2.5542e-05 - val_accuracy: 0.5700 - val_loss: 4.4547
# Epoch 163/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.8225e-05 - val_accuracy: 0.5750 - val_loss: 4.4593
# Epoch 164/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.8384e-05 - val_accuracy: 0.5750 - val_loss: 4.4604
# Epoch 165/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.9209e-05 - val_accuracy: 0.5750 - val_loss: 4.4673
# Epoch 166/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 2.2959e-05 - val_accuracy: 0.5750 - val_loss: 4.4730
# Epoch 167/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.4126e-05 - val_accuracy: 0.5750 - val_loss: 4.4814
# Epoch 168/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 3.7358e-05 - val_accuracy: 0.5700 - val_loss: 4.4858
# Epoch 169/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 2.6224e-05 - val_accuracy: 0.5700 - val_loss: 4.4916
# Epoch 170/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 1.0000 - loss: 2.6273e-05 - val_accuracy: 0.5700 - val_loss: 4.4969
# Epoch 171/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.1446e-05 - val_accuracy: 0.5700 - val_loss: 4.5038
# Epoch 172/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 2.6579e-05 - val_accuracy: 0.5700 - val_loss: 4.5098
# Epoch 173/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.9747e-05 - val_accuracy: 0.5700 - val_loss: 4.5136
# Epoch 174/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 2.8948e-05 - val_accuracy: 0.5700 - val_loss: 4.5149
# Epoch 175/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.2814e-05 - val_accuracy: 0.5700 - val_loss: 4.5224
# Epoch 176/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.9655e-05 - val_accuracy: 0.5700 - val_loss: 4.5286
# Epoch 177/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.3567e-05 - val_accuracy: 0.5700 - val_loss: 4.5329
# Epoch 178/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 2.0683e-05 - val_accuracy: 0.5750 - val_loss: 4.5363
# Epoch 179/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.9280e-05 - val_accuracy: 0.5700 - val_loss: 4.5431
# Epoch 180/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.4934e-05 - val_accuracy: 0.5700 - val_loss: 4.5499
# Epoch 181/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 2.7740e-05 - val_accuracy: 0.5750 - val_loss: 4.5551
# Epoch 182/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.9568e-05 - val_accuracy: 0.5750 - val_loss: 4.5613
# Epoch 183/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.3027e-05 - val_accuracy: 0.5700 - val_loss: 4.5683
# Epoch 184/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.5082e-05 - val_accuracy: 0.5700 - val_loss: 4.5754
# Epoch 185/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.6179e-05 - val_accuracy: 0.5700 - val_loss: 4.5832
# Epoch 186/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.8769e-05 - val_accuracy: 0.5700 - val_loss: 4.5860
# Epoch 187/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.0205e-05 - val_accuracy: 0.5700 - val_loss: 4.5932
# Epoch 188/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 1.7550e-05 - val_accuracy: 0.5700 - val_loss: 4.5949
# Epoch 189/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 2.1074e-05 - val_accuracy: 0.5700 - val_loss: 4.6019
# Epoch 190/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 1.7690e-05 - val_accuracy: 0.5700 - val_loss: 4.6083
# Epoch 191/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.4786e-05 - val_accuracy: 0.5700 - val_loss: 4.6165
# Epoch 192/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.2388e-05 - val_accuracy: 0.5700 - val_loss: 4.6230
# Epoch 193/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.2011e-05 - val_accuracy: 0.5700 - val_loss: 4.6276
# Epoch 194/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.5829e-05 - val_accuracy: 0.5700 - val_loss: 4.6309
# Epoch 195/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.2841e-05 - val_accuracy: 0.5700 - val_loss: 4.6351
# Epoch 196/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.1186e-05 - val_accuracy: 0.5700 - val_loss: 4.6408
# Epoch 197/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.6699e-05 - val_accuracy: 0.5700 - val_loss: 4.6462
# Epoch 198/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.5026e-05 - val_accuracy: 0.5700 - val_loss: 4.6538
# Epoch 199/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.6031e-05 - val_accuracy: 0.5700 - val_loss: 4.6612
# Epoch 200/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.3514e-05 - val_accuracy: 0.5700 - val_loss: 4.6584
# Epoch 201/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.0589e-05 - val_accuracy: 0.5700 - val_loss: 4.6667
# Epoch 202/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.2059e-05 - val_accuracy: 0.5700 - val_loss: 4.6739
# Epoch 203/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.6196e-05 - val_accuracy: 0.5700 - val_loss: 4.6767
# Epoch 204/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.8465e-05 - val_accuracy: 0.5700 - val_loss: 4.6830
# Epoch 205/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.4857e-05 - val_accuracy: 0.5700 - val_loss: 4.6857
# Epoch 206/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.4626e-05 - val_accuracy: 0.5700 - val_loss: 4.6903
# Epoch 207/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 1.6786e-05 - val_accuracy: 0.5700 - val_loss: 4.6912
# Epoch 208/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 1.5465e-05 - val_accuracy: 0.5700 - val_loss: 4.6973
# Epoch 209/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 1.2268e-05 - val_accuracy: 0.5700 - val_loss: 4.7020
# Epoch 210/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.7342e-05 - val_accuracy: 0.5700 - val_loss: 4.7092
# Epoch 211/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.2074e-05 - val_accuracy: 0.5700 - val_loss: 4.7073
# Epoch 212/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 2.1071e-05 - val_accuracy: 0.5700 - val_loss: 4.7119
# Epoch 213/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 1.0000 - loss: 1.2772e-05 - val_accuracy: 0.5700 - val_loss: 4.7158
# Epoch 214/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.0646e-05 - val_accuracy: 0.5700 - val_loss: 4.7220
# Epoch 215/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.2298e-05 - val_accuracy: 0.5700 - val_loss: 4.7299
# Epoch 216/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.1500e-05 - val_accuracy: 0.5700 - val_loss: 4.7369
# Epoch 217/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.5324e-05 - val_accuracy: 0.5700 - val_loss: 4.7402
# Epoch 218/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.5283e-05 - val_accuracy: 0.5700 - val_loss: 4.7505
# Epoch 219/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.3666e-05 - val_accuracy: 0.5700 - val_loss: 4.7590
# Epoch 220/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.8544e-05 - val_accuracy: 0.5700 - val_loss: 4.7704
# Epoch 221/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.6999e-05 - val_accuracy: 0.5700 - val_loss: 4.7755
# Epoch 222/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.0663e-05 - val_accuracy: 0.5700 - val_loss: 4.7797
# Epoch 223/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.4909e-05 - val_accuracy: 0.5700 - val_loss: 4.7878
# Epoch 224/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 9.9264e-06 - val_accuracy: 0.5700 - val_loss: 4.7963
# Epoch 225/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.2686e-05 - val_accuracy: 0.5700 - val_loss: 4.8027
# Epoch 226/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.1919e-05 - val_accuracy: 0.5700 - val_loss: 4.8086
# Epoch 227/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 9.3580e-06 - val_accuracy: 0.5700 - val_loss: 4.8121
# Epoch 228/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 1.4997e-05 - val_accuracy: 0.5700 - val_loss: 4.8164
# Epoch 229/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 9.6226e-06 - val_accuracy: 0.5700 - val_loss: 4.8211
# Epoch 230/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 9.1916e-06 - val_accuracy: 0.5700 - val_loss: 4.8192
# Epoch 231/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.0220e-05 - val_accuracy: 0.5700 - val_loss: 4.8229
# Epoch 232/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.1168e-05 - val_accuracy: 0.5700 - val_loss: 4.8292
# Epoch 233/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.1142e-05 - val_accuracy: 0.5700 - val_loss: 4.8401
# Epoch 234/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.2689e-05 - val_accuracy: 0.5700 - val_loss: 4.8457
# Epoch 235/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.5267e-05 - val_accuracy: 0.5700 - val_loss: 4.8455
# Epoch 236/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 8.8184e-06 - val_accuracy: 0.5700 - val_loss: 4.8505
# Epoch 237/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.4316e-05 - val_accuracy: 0.5700 - val_loss: 4.8597
# Epoch 238/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 8.2552e-06 - val_accuracy: 0.5700 - val_loss: 4.8621
# Epoch 239/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 8.1802e-06 - val_accuracy: 0.5700 - val_loss: 4.8643
# Epoch 240/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 8.8995e-06 - val_accuracy: 0.5700 - val_loss: 4.8734
# Epoch 241/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 7.7863e-06 - val_accuracy: 0.5700 - val_loss: 4.8795
# Epoch 242/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 7.8045e-06 - val_accuracy: 0.5700 - val_loss: 4.8805
# Epoch 243/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.0005e-05 - val_accuracy: 0.5700 - val_loss: 4.8846
# Epoch 244/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.1338e-05 - val_accuracy: 0.5700 - val_loss: 4.8921
# Epoch 245/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 8.8589e-06 - val_accuracy: 0.5700 - val_loss: 4.9007
# Epoch 246/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 7.7549e-06 - val_accuracy: 0.5700 - val_loss: 4.9072
# Epoch 247/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 1.0000 - loss: 1.1107e-05 - val_accuracy: 0.5700 - val_loss: 4.9049
# Epoch 248/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 1.3705e-05 - val_accuracy: 0.5650 - val_loss: 4.9171
# Epoch 249/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 1.0000 - loss: 6.9865e-06 - val_accuracy: 0.5650 - val_loss: 4.9204
# Epoch 250/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 8.3824e-06 - val_accuracy: 0.5650 - val_loss: 4.9230
# Epoch 251/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 7.8389e-06 - val_accuracy: 0.5650 - val_loss: 4.9300
# Epoch 252/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 6.4484e-06 - val_accuracy: 0.5650 - val_loss: 4.9343
# Epoch 253/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 1.0000 - loss: 7.3473e-06 - val_accuracy: 0.5700 - val_loss: 4.9363
# Epoch 254/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 8.6465e-06 - val_accuracy: 0.5700 - val_loss: 4.9423
# Epoch 255/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 6.5557e-06 - val_accuracy: 0.5700 - val_loss: 4.9470
# Epoch 256/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 5.5429e-06 - val_accuracy: 0.5700 - val_loss: 4.9538
# Epoch 257/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 7.2133e-06 - val_accuracy: 0.5700 - val_loss: 4.9561
# Epoch 258/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 7.1772e-06 - val_accuracy: 0.5700 - val_loss: 4.9609
# Epoch 259/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 5.6582e-06 - val_accuracy: 0.5700 - val_loss: 4.9633
# Epoch 260/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 8.9065e-06 - val_accuracy: 0.5700 - val_loss: 4.9650
# Epoch 261/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 5.3914e-06 - val_accuracy: 0.5700 - val_loss: 4.9699
# Epoch 262/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 5.2036e-06 - val_accuracy: 0.5700 - val_loss: 4.9742
# Epoch 263/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 8.5605e-06 - val_accuracy: 0.5700 - val_loss: 4.9787
# Epoch 264/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 5.9426e-06 - val_accuracy: 0.5700 - val_loss: 4.9900
# Epoch 265/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 6.1433e-06 - val_accuracy: 0.5700 - val_loss: 4.9985
# Epoch 266/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 1.0000 - loss: 6.1019e-06 - val_accuracy: 0.5700 - val_loss: 5.0010
# Epoch 267/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 5.3366e-06 - val_accuracy: 0.5700 - val_loss: 5.0055
# Epoch 268/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 1.0000 - loss: 6.2048e-06 - val_accuracy: 0.5700 - val_loss: 5.0103
# Epoch 269/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 5.3951e-06 - val_accuracy: 0.5700 - val_loss: 5.0120
# Epoch 270/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 8.1531e-06 - val_accuracy: 0.5700 - val_loss: 5.0124
# Epoch 271/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 6.6614e-06 - val_accuracy: 0.5750 - val_loss: 5.0235
# Epoch 272/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 5.1074e-06 - val_accuracy: 0.5750 - val_loss: 5.0320
# Epoch 273/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 5.8509e-06 - val_accuracy: 0.5750 - val_loss: 5.0364
# Epoch 274/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.6678e-06 - val_accuracy: 0.5750 - val_loss: 5.0338
# Epoch 275/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 5.7972e-06 - val_accuracy: 0.5750 - val_loss: 5.0399
# Epoch 276/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 6.4584e-06 - val_accuracy: 0.5750 - val_loss: 5.0480
# Epoch 277/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 6.7310e-06 - val_accuracy: 0.5750 - val_loss: 5.0504
# Epoch 278/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 6.0767e-06 - val_accuracy: 0.5750 - val_loss: 5.0620
# Epoch 279/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.9482e-06 - val_accuracy: 0.5750 - val_loss: 5.0703
# Epoch 280/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 5.9388e-06 - val_accuracy: 0.5700 - val_loss: 5.0764
# Epoch 281/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.6749e-06 - val_accuracy: 0.5700 - val_loss: 5.0834
# Epoch 282/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.1285e-06 - val_accuracy: 0.5700 - val_loss: 5.0849
# Epoch 283/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 5.5788e-06 - val_accuracy: 0.5700 - val_loss: 5.0897
# Epoch 284/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.9662e-06 - val_accuracy: 0.5700 - val_loss: 5.0956
# Epoch 285/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 4.8665e-06 - val_accuracy: 0.5700 - val_loss: 5.0976
# Epoch 286/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 1.0000 - loss: 4.8925e-06 - val_accuracy: 0.5700 - val_loss: 5.1040
# Epoch 287/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 5.5116e-06 - val_accuracy: 0.5700 - val_loss: 5.1105
# Epoch 288/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 3.7999e-06 - val_accuracy: 0.5700 - val_loss: 5.1142
# Epoch 289/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 4.4523e-06 - val_accuracy: 0.5700 - val_loss: 5.1147
# Epoch 290/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 5.0514e-06 - val_accuracy: 0.5700 - val_loss: 5.1165
# Epoch 291/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.0595e-06 - val_accuracy: 0.5700 - val_loss: 5.1213
# Epoch 292/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 4.3427e-06 - val_accuracy: 0.5700 - val_loss: 5.1311
# Epoch 293/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.2012e-06 - val_accuracy: 0.5700 - val_loss: 5.1374
# Epoch 294/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.2956e-06 - val_accuracy: 0.5700 - val_loss: 5.1422
# Epoch 295/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.2545e-06 - val_accuracy: 0.5700 - val_loss: 5.1451
# Epoch 296/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.3339e-06 - val_accuracy: 0.5700 - val_loss: 5.1484
# Epoch 297/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 4.0270e-06 - val_accuracy: 0.5700 - val_loss: 5.1496
# Epoch 298/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 1.0000 - loss: 2.8126e-06 - val_accuracy: 0.5700 - val_loss: 5.1540
# Epoch 299/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.4511e-06 - val_accuracy: 0.5700 - val_loss: 5.1565
# Epoch 300/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.9056e-06 - val_accuracy: 0.5700 - val_loss: 5.1603
# Epoch 301/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.3419e-06 - val_accuracy: 0.5700 - val_loss: 5.1667
# Epoch 302/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 5.6993e-06 - val_accuracy: 0.5700 - val_loss: 5.1780
# Epoch 303/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 3.5381e-06 - val_accuracy: 0.5700 - val_loss: 5.1837
# Epoch 304/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 3.6599e-06 - val_accuracy: 0.5700 - val_loss: 5.1853
# Epoch 305/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 4.1023e-06 - val_accuracy: 0.5700 - val_loss: 5.1939
# Epoch 306/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 1.0000 - loss: 2.5253e-06 - val_accuracy: 0.5700 - val_loss: 5.1994
# Epoch 307/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 3.4584e-06 - val_accuracy: 0.5700 - val_loss: 5.2024
# Epoch 308/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.3271e-06 - val_accuracy: 0.5700 - val_loss: 5.2101
# Epoch 309/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.3958e-06 - val_accuracy: 0.5700 - val_loss: 5.2157
# Epoch 310/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.7294e-06 - val_accuracy: 0.5700 - val_loss: 5.2205
# Epoch 311/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.1613e-06 - val_accuracy: 0.5700 - val_loss: 5.2263
# Epoch 312/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.9395e-06 - val_accuracy: 0.5700 - val_loss: 5.2323
# Epoch 313/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 3.4068e-06 - val_accuracy: 0.5700 - val_loss: 5.2322
# Epoch 314/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.3758e-06 - val_accuracy: 0.5700 - val_loss: 5.2358
# Epoch 315/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.9679e-06 - val_accuracy: 0.5700 - val_loss: 5.2435
# Epoch 316/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 2.7585e-06 - val_accuracy: 0.5700 - val_loss: 5.2480
# Epoch 317/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.8317e-06 - val_accuracy: 0.5700 - val_loss: 5.2492
# Epoch 318/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 3.0067e-06 - val_accuracy: 0.5700 - val_loss: 5.2530
# Epoch 319/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 2.4695e-06 - val_accuracy: 0.5700 - val_loss: 5.2587
# Epoch 320/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.1170e-06 - val_accuracy: 0.5700 - val_loss: 5.2622
# Epoch 321/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.2494e-06 - val_accuracy: 0.5700 - val_loss: 5.2683
# Epoch 322/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 4.6315e-06 - val_accuracy: 0.5700 - val_loss: 5.2641
# Epoch 323/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 2.6113e-06 - val_accuracy: 0.5750 - val_loss: 5.2683
# Epoch 324/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 2.6933e-06 - val_accuracy: 0.5700 - val_loss: 5.2724
# Epoch 325/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 3.0012e-06 - val_accuracy: 0.5750 - val_loss: 5.2804
# Epoch 326/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 3.4798e-06 - val_accuracy: 0.5700 - val_loss: 5.2892
# Epoch 327/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 1.5250e-06 - val_accuracy: 0.5700 - val_loss: 5.2948
# Epoch 328/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.6248e-06 - val_accuracy: 0.5700 - val_loss: 5.2968
# Epoch 329/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.3698e-06 - val_accuracy: 0.5700 - val_loss: 5.3021
# Epoch 330/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.1199e-06 - val_accuracy: 0.5700 - val_loss: 5.3128
# Epoch 331/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.3830e-06 - val_accuracy: 0.5700 - val_loss: 5.3183
# Epoch 332/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 3.7426e-06 - val_accuracy: 0.5700 - val_loss: 5.3348
# Epoch 333/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 1.0000 - loss: 3.1521e-06 - val_accuracy: 0.5700 - val_loss: 5.3392
# Epoch 334/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.4736e-06 - val_accuracy: 0.5700 - val_loss: 5.3410
# Epoch 335/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 2.2060e-06 - val_accuracy: 0.5700 - val_loss: 5.3472
# Epoch 336/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 2.4750e-06 - val_accuracy: 0.5700 - val_loss: 5.3520
# Epoch 337/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 4.6745e-06 - val_accuracy: 0.5700 - val_loss: 5.3665
# Epoch 338/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 2.6710e-06 - val_accuracy: 0.5700 - val_loss: 5.3734
# Epoch 339/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 1.9421e-06 - val_accuracy: 0.5750 - val_loss: 5.3790
# Epoch 340/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - accuracy: 1.0000 - loss: 2.0542e-06 - val_accuracy: 0.5750 - val_loss: 5.3829
# Epoch 341/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 1.0000 - loss: 1.9429e-06 - val_accuracy: 0.5700 - val_loss: 5.3810
# Epoch 342/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 1.0000 - loss: 2.1579e-06 - val_accuracy: 0.5700 - val_loss: 5.3888
# Epoch 343/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 1.0000 - loss: 1.5728e-06 - val_accuracy: 0.5700 - val_loss: 5.3931
# Epoch 344/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 2.0013e-06 - val_accuracy: 0.5700 - val_loss: 5.3946
# Epoch 345/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.5574e-06 - val_accuracy: 0.5700 - val_loss: 5.3953
# Epoch 346/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.5763e-06 - val_accuracy: 0.5700 - val_loss: 5.4052
# Epoch 347/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.3793e-06 - val_accuracy: 0.5700 - val_loss: 5.4092
# Epoch 348/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.8619e-06 - val_accuracy: 0.5700 - val_loss: 5.4053
# Epoch 349/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.4275e-06 - val_accuracy: 0.5700 - val_loss: 5.4104
# Epoch 350/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 1.0000 - loss: 2.0936e-06 - val_accuracy: 0.5700 - val_loss: 5.4123
# Epoch 351/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 1.0000 - loss: 1.3997e-06 - val_accuracy: 0.5750 - val_loss: 5.4188
# Epoch 352/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 1.0000 - loss: 1.8278e-06 - val_accuracy: 0.5750 - val_loss: 5.4242
# Epoch 353/1000
# ...
# Epoch 861/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 1.0000 - loss: 4.9402e-07 - val_accuracy: 0.5650 - val_loss: 5.6912
# Epoch 862/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 5.8503e-07 - val_accuracy: 0.5650 - val_loss: 5.6974
# Epoch 863/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 5.3765e-07 - val_accuracy: 0.5650 - val_loss: 5.7011
# Epoch 864/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 7.3112e-07 - val_accuracy: 0.5650 - val_loss: 5.7040
# Epoch 865/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 5.5511e-07 - val_accuracy: 0.5650 - val_loss: 5.7121
# Epoch 866/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 6.6887e-07 - val_accuracy: 0.5600 - val_loss: 5.7456
# Epoch 867/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 6.0545e-07 - val_accuracy: 0.5600 - val_loss: 5.7500
# Epoch 868/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 9.1150e-07 - val_accuracy: 0.5600 - val_loss: 5.7488
# Epoch 869/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 6.7871e-07 - val_accuracy: 0.5600 - val_loss: 5.7477
# Epoch 870/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 1.0000 - loss: 1.0761e-06 - val_accuracy: 0.5650 - val_loss: 5.7493
# Epoch 871/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 1.0000 - loss: 7.8400e-07 - val_accuracy: 0.5650 - val_loss: 5.7483
# Epoch 872/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 1.0000 - loss: 4.8386e-07 - val_accuracy: 0.5650 - val_loss: 5.7479
# Epoch 873/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 5.2005e-07 - val_accuracy: 0.5650 - val_loss: 5.7512
# Epoch 874/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 7.6877e-07 - val_accuracy: 0.5650 - val_loss: 5.7586
# Epoch 875/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 1.0000 - loss: 6.7902e-07 - val_accuracy: 0.5650 - val_loss: 5.7651
# Epoch 876/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 4.1692e-07 - val_accuracy: 0.5600 - val_loss: 5.7706
# Epoch 877/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 4.1647e-07 - val_accuracy: 0.5600 - val_loss: 5.7728
# Epoch 878/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 6.3599e-07 - val_accuracy: 0.5600 - val_loss: 5.7755
# Epoch 879/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 1.0000 - loss: 3.9311e-07 - val_accuracy: 0.5600 - val_loss: 5.7792
# Epoch 880/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 4.6010e-07 - val_accuracy: 0.5600 - val_loss: 5.7832
# Epoch 881/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 1.0000 - loss: 5.1390e-07 - val_accuracy: 0.5600 - val_loss: 5.7875
# Epoch 882/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 7.4515e-07 - val_accuracy: 0.5600 - val_loss: 5.7918
# Epoch 883/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 1.0000 - loss: 6.0514e-07 - val_accuracy: 0.5650 - val_loss: 5.8030
# Epoch 884/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 1.0000 - loss: 4.6750e-07 - val_accuracy: 0.5650 - val_loss: 5.8083
# Epoch 885/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 5.4992e-07 - val_accuracy: 0.5650 - val_loss: 5.8090
# Epoch 886/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 5.3507e-07 - val_accuracy: 0.5650 - val_loss: 5.8147
# Epoch 887/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 5.7697e-07 - val_accuracy: 0.5650 - val_loss: 5.8235
# Epoch 888/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 5.0512e-07 - val_accuracy: 0.5650 - val_loss: 5.8283
# Epoch 889/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 3.9559e-07 - val_accuracy: 0.5600 - val_loss: 5.8329
# Epoch 890/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 6.9785e-07 - val_accuracy: 0.5600 - val_loss: 5.8367
# Epoch 891/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 3.9836e-07 - val_accuracy: 0.5600 - val_loss: 5.8449
# Epoch 892/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 3.5820e-07 - val_accuracy: 0.5600 - val_loss: 5.8530
# Epoch 893/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 3.9307e-07 - val_accuracy: 0.5600 - val_loss: 5.8600
# Epoch 894/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 4.5512e-07 - val_accuracy: 0.5600 - val_loss: 5.8659
# Epoch 895/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 6.9170e-07 - val_accuracy: 0.5600 - val_loss: 5.8760
# Epoch 896/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 3.3331e-07 - val_accuracy: 0.5600 - val_loss: 5.8833
# Epoch 897/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 3.1300e-07 - val_accuracy: 0.5600 - val_loss: 5.8891
# Epoch 898/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 3.7012e-07 - val_accuracy: 0.5600 - val_loss: 5.8943
# Epoch 899/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 1.0000 - loss: 4.4810e-07 - val_accuracy: 0.5600 - val_loss: 5.9029
# Epoch 900/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 1.0000 - loss: 3.0755e-07 - val_accuracy: 0.5600 - val_loss: 5.9103
# Epoch 901/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 3.8049e-07 - val_accuracy: 0.5600 - val_loss: 5.9149
# Epoch 902/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 3.4313e-07 - val_accuracy: 0.5600 - val_loss: 5.9218
# Epoch 903/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.4939e-07 - val_accuracy: 0.5600 - val_loss: 5.9261
# Epoch 904/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 1.0000 - loss: 4.4415e-07 - val_accuracy: 0.5600 - val_loss: 5.9308
# Epoch 905/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 3.9382e-07 - val_accuracy: 0.5600 - val_loss: 5.9370
# Epoch 906/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.9087e-07 - val_accuracy: 0.5600 - val_loss: 5.9419
# Epoch 907/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 2.9769e-07 - val_accuracy: 0.5600 - val_loss: 5.9473
# Epoch 908/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 5.6013e-07 - val_accuracy: 0.5600 - val_loss: 5.9560
# Epoch 909/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.7918e-07 - val_accuracy: 0.5550 - val_loss: 5.9614
# Epoch 910/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 2.9534e-07 - val_accuracy: 0.5550 - val_loss: 5.9637
# Epoch 911/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 5.0872e-07 - val_accuracy: 0.5600 - val_loss: 5.9663
# Epoch 912/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 1.0000 - loss: 2.8540e-07 - val_accuracy: 0.5600 - val_loss: 5.9692
# Epoch 913/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 1.0000 - loss: 5.4513e-07 - val_accuracy: 0.5600 - val_loss: 5.9672
# Epoch 914/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 2.5003e-07 - val_accuracy: 0.5600 - val_loss: 5.9720
# Epoch 915/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 6.5828e-07 - val_accuracy: 0.5600 - val_loss: 5.9751
# Epoch 916/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 2.3722e-07 - val_accuracy: 0.5600 - val_loss: 5.9797
# Epoch 917/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 1.0000 - loss: 3.1255e-07 - val_accuracy: 0.5600 - val_loss: 5.9842
# Epoch 918/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 3.4175e-07 - val_accuracy: 0.5550 - val_loss: 5.9939
# Epoch 919/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.8662e-07 - val_accuracy: 0.5550 - val_loss: 6.0013
# Epoch 920/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 3.7465e-07 - val_accuracy: 0.5550 - val_loss: 6.0124
# Epoch 921/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 4.3010e-07 - val_accuracy: 0.5550 - val_loss: 6.0147
# Epoch 922/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 3.0137e-07 - val_accuracy: 0.5550 - val_loss: 6.0205
# Epoch 923/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.8504e-07 - val_accuracy: 0.5600 - val_loss: 6.0241
# Epoch 924/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.6765e-07 - val_accuracy: 0.5600 - val_loss: 6.0256
# Epoch 925/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 1.0000 - loss: 2.2588e-07 - val_accuracy: 0.5600 - val_loss: 6.0290
# Epoch 926/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 3.0865e-07 - val_accuracy: 0.5600 - val_loss: 6.0337
# Epoch 927/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 1.0000 - loss: 4.2830e-07 - val_accuracy: 0.5600 - val_loss: 6.0376
# Epoch 928/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 3.9672e-07 - val_accuracy: 0.5600 - val_loss: 6.0371
# Epoch 929/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 1.0000 - loss: 2.5096e-07 - val_accuracy: 0.5600 - val_loss: 6.0404
# Epoch 930/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 5.3001e-07 - val_accuracy: 0.5650 - val_loss: 5.9559
# Epoch 931/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 4.8606e-07 - val_accuracy: 0.5700 - val_loss: 5.9647
# Epoch 932/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.6678e-07 - val_accuracy: 0.5650 - val_loss: 5.9765
# Epoch 933/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 2.7790e-07 - val_accuracy: 0.5700 - val_loss: 5.9905
# Epoch 934/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 1.0000 - loss: 2.6597e-07 - val_accuracy: 0.5650 - val_loss: 6.0026
# Epoch 935/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 1.0000 - loss: 2.4171e-07 - val_accuracy: 0.5650 - val_loss: 6.0067
# Epoch 936/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 1.0000 - loss: 2.6135e-07 - val_accuracy: 0.5650 - val_loss: 6.0131
# Epoch 937/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 1.0000 - loss: 1.8442e-07 - val_accuracy: 0.5650 - val_loss: 6.0215
# Epoch 938/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 1.0000 - loss: 2.4002e-07 - val_accuracy: 0.5650 - val_loss: 6.0287
# Epoch 939/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 1.0000 - loss: 2.3168e-07 - val_accuracy: 0.5650 - val_loss: 6.0373
# Epoch 940/1000
# 11/25 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 2.2154e-07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-729546258e90> in <cell line: 0>()
#      64
#      65 # 8) 모델 학습
# ---> 66 history = model.fit(
#      67     train_dataset,
#      68     epochs=num_epochs,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369                 for step, iterator in epoch_iterator:
#     370                     callbacks.on_train_batch_begin(step)
# --> 371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#     373                     if self.stop_training:
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     217                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218             ):
# --> 219                 opt_outputs = multi_step_on_iterator(iterator)
#     220                 if not opt_outputs.has_value():
#     221                     raise StopIteration
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1681     cancellation_context = cancellation.context()
#    1682     if cancellation_context is None:
# -> 1683       outputs = execute.execute(
#    1684           name.decode("utf-8"),
#    1685           num_outputs=num_outputs,
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# ### 트랜스포머의 전체 아키텍처
#
# - **인코더-디코더 구조**
#     - 인코더: 입력 시퀀스를 표현(representation)으로 변환
#     - 디코더: 표현을 출력 시퀀스로 변환
# - **인코더 블록 구성 요소**
#     - 멀티-헤드 셀프-어텐션(Multi-Head Self-Attention)
#     - 포지션-와이즈 피드-포워드 네트워크(Position-wise Feed-Forward Network)
#     - 레이어 정규화(Layer Normalization)와 잔차 연결(Residual Connection)
# - **디코더 블록 구성 요소**
#     - 마스크드 멀티-헤드 셀프-어텐션(Masked Multi-Head Self-Attention)
#     - 인코더-디코더 어텐션(Encoder-Decoder Attention)
#     - 포지션-와이즈 피드-포워드 네트워크
# - **위치 인코딩(Positional Encoding)**
#     - 순서 정보를 모델에 제공하는 방법
#     - 사인/코사인 함수를 이용한 위치 표현
#
# ### 3.5 PyTorch를 이용한 간단한 트랜스포머 구현

# %%
import torch
import torch.nn as nn
import math

# 위치 인코딩 구현
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length=5000):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        return x + self.pe[:, :x.size(1), :]

# 간단한 트랜스포머 인코더 레이어
class SimpleTransformerEncoder(nn.Module):
    def __init__(self, d_model, nhead, dim_feedforward=2048, dropout=0.1):
        super(SimpleTransformerEncoder, self).__init__()
        self.self_attn = nn.MultiheadAttention(d_model, nhead, dropout=dropout)

        # 피드포워드 신경망
        self.linear1 = nn.Linear(d_model, dim_feedforward)
        self.dropout = nn.Dropout(dropout)
        self.linear2 = nn.Linear(dim_feedforward, d_model)

        # 레이어 정규화
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)

        self.activation = nn.ReLU()

    def forward(self, src, src_mask=None):
        # 멀티헤드 어텐션
        src2, _ = self.self_attn(src, src, src, attn_mask=src_mask)
        src = src + self.dropout1(src2)  # 잔차 연결
        src = self.norm1(src)  # 레이어 정규화

        # 피드포워드 신경망
        src2 = self.linear2(self.dropout(self.activation(self.linear1(src))))
        src = src + self.dropout2(src2)  # 잔차 연결
        src = self.norm2(src)  # 레이어 정규화

        return src

# 전체 트랜스포머 인코더 모델
class TransformerEncoderModel(nn.Module):
    def __init__(self, vocab_size, d_model, nhead, dim_feedforward, num_layers, max_seq_length, dropout=0.1):
        super(TransformerEncoderModel, self).__init__()
        self.d_model = d_model

        # 임베딩 레이어
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.pos_encoder = PositionalEncoding(d_model, max_seq_length)

        # 트랜스포머 인코더 레이어 스택
        encoder_layers = []
        for _ in range(num_layers):
            encoder_layers.append(SimpleTransformerEncoder(d_model, nhead, dim_feedforward, dropout))
        self.encoder_layers = nn.ModuleList(encoder_layers)

        self.dropout = nn.Dropout(dropout)

    def forward(self, src):
        # 임베딩 및 위치 인코딩
        src = self.embedding(src) * math.sqrt(self.d_model)
        src = self.pos_encoder(src)
        src = self.dropout(src)

        # 인코더 레이어 통과
        for encoder_layer in self.encoder_layers:
            src = encoder_layer(src)

        return src

# 모델 파라미터 설정
vocab_size = 10000
d_model = 512
nhead = 8
dim_feedforward = 2048
num_layers = 2
max_seq_length = 100
batch_size = 16
seq_length = 30

# 모델 인스턴스 생성
model = TransformerEncoderModel(vocab_size, d_model, nhead, dim_feedforward, num_layers, max_seq_length)

# 가상의 입력 데이터 (배치 크기, 시퀀스 길이)
src = torch.randint(0, vocab_size, (batch_size, seq_length))
# print(src[0].shape)
output = model(src)

print(f"입력 크기: {src.shape}")
print(f"출력 크기: {output.shape}")
# Out:
# 입력 크기: torch.Size([16, 30])
# 출력 크기: torch.Size([16, 30, 512])

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9598049521446228}]

# %%
from transformers import pipeline

answer = pipeline("question-answering")
answer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn"
)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Device set to use cpu
# {'score': 0.6949766278266907, 'start': 33, 'end': 45, 'answer': 'Hugging Face'}

# %%
from transformers import pipeline

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
# Out:
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/models/marian/tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Device set to use cpu
# [{'translation_text': 'This course is produced by Hugging Face.'}]
